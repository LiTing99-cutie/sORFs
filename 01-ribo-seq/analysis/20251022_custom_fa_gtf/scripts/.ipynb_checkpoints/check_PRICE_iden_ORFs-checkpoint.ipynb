# %%
source("/home/user/data2/lit/bin/lit_utils.R")
source("/home/user/data3/lit/project/sORFs/sORFs.utils.R")
lib_text()
lib_plot()

# %%
fread_c("/home/user/data3/lit/project/sORFs/01-ribo-seq/analysis/20251022_custom_fa_gtf/processed/orfs/PRICE/Human_brain.orfs.tsv") -> orfs

# %%
head(orfs)
nrow(orfs)
# Out:
#   Gene      Id                 Location               Candidate Location
# 1 WARS2-IT1 PB.2462.1_ncRNA_1  1+:119047264-119047276 1+:119047264-119047276
# 2 WARS2-IT1 PB.2462.1_ncRNA_0  1+:119047334-119047367 1+:119047319-119047367
# 3 WARS2-IT1 PB.2462.1_ncRNA_2  1+:119047477-119047486 1+:119047477-119047486
# 4 PAPPA2    PB.3326.2_ncRNA_0  1+:176555485-176555536 1+:176555485-176555536
# 5 LINC00623 PB.2508.71_ncRNA_1 1+:120942451-120942526 1+:120942451-120942526
# 6 LINC00623 PB.2508.71_ncRNA_2 1+:120952453-120952498 1+:120952453-120952498
#   Codon Type  Start Range p value
# 1 ATG   ncRNA 0.42  0.27  0.7558600
# 2 ATA   ncRNA 0.12  0.20  0.0088559
# 3 ATG   ncRNA 0.47  0.24  0.4375000
# 4 AAG   ncRNA 0.42  0.25  0.1162100
# 5 AAG   ncRNA 0.13  0.25  0.3567300
# 6 ACG   ncRNA 0.47  0.29  0.7388100
#   /home/user/data3/lit/project/sORFs/01-ribo-seq/analysis/20251022_custom_fa_gtf/processed/merged_bam/
# 1 11.0
# 2 20.0
# 3  6.6
# 4 14.1
# 5 44.5
# 6 32.5
#   Total
# 1 11.0
# 2 20.0
# 3  6.6
# 4 14.1
# 5 44.5
# 6 32.5
# [1] 193397

# %%
orfs %>% filter(`p value`<=0.05) %>% nrow()
orfs %>% filter(`p value`<=0.05 & Codon=="ATG" & Type!="CDS") %>% nrow()
# Out:
# [1] 29197
# [1] 5622

# %%
adjusted_p <- p.adjust(orfs$`p value`, method = "BH")

# %%
sum(adjusted_p<=0.05)
orfs$adjusted_P <- adjusted_p
# Out:
# [1] 18334

# %%
# orfs %>% filter(adjusted_P<=0.05) %>% count(Type)
orfs %>% filter(adjusted_P<=0.05) %>% 
filter(Codon %in% c("ATG","TTG","CTG","GTG","ACG")) %>% 
filter(Type!="Trunc" & Type!="Variant") %>% count(Type) -> tmp
tmp
tmp %>% summarise(sum(n))
# Out:
#   Type   n
# 1 CDS    1392
# 2 dORF    561
# 3 iORF    184
# 4 ncRNA  3598
# 5 orphan   13
# 6 uORF   1717
# 7 uoORF   675
#   sum(n)
# 1 8140

# %%
fread_c("/home/user/data3/lit/project/sORFs/01-ribo-seq/analysis/20251022_custom_fa_gtf/processed/orfs/RiboCode/Human_brain_collapsed.txt") -> ribocode_orfs
head(ribocode_orfs,1) %>% print()
# Out:
#                      ORF_ID ORF_type alt_ORF_type transcript_id transcript_type
# 1 A1BG_58347580_58347503_25    novel            -    PB.22711.2            None
#   gene_id gene_name gene_type chrom start_codon strand ORF_length ORF_tstart
# 1    A1BG      A1BG      None chr19         ATG      -         75         43
#   ORF_tstop ORF_gstart ORF_gstop annotated_tstart annotated_tstop
# 1       120   58347580  58347503             None            None
#   annotated_gstart annotated_gstop Psites_sum_frame0 Psites_sum_frame1
# 1             None            None                73                12
#   Psites_sum_frame2 Psites_coverage_frame0 Psites_coverage_frame1
# 1                11                 24.00%                 12.00%
#   Psites_coverage_frame2 Psites_frame0_RPKM pval_frame0_vs_frame1
# 1                 12.00%           4.712767            0.02427537
#   pval_frame0_vs_frame2 pval_combined adjusted_pval                     AAseq
# 1            0.05352897   0.005633231    0.01832241 MPSCAARDPSPTSPSSCCARARRRP

# %%
table(ribocode_orfs$ORF_type)
# Out:
#    annotated         dORF     internal        novel Overlap_dORF Overlap_uORF
#        20930        19027        24554        86672         3250         6810
#         uORF
#        18708
