# %%
file_path <- "../../results/S5/unique_methods_protein_features_added.txt"
out_plot_1 <- "../../figures/GRAVY_by_enrich.pdf"
out_plot_1_1 <- "../../figures/GRAVY_by_enrich.mean_CI.pdf"
out_plot_2 <- "../../figures/pI_by_enrich.pdf"

# %%
source("/home/user/data2/lit/bin/lit_utils.R")
source("/home/user/data3/lit/project/sORFs/sORFs.utils.R")
lib_text()
lib_plot()

fread_c(file_path) -> df
head(df)
colnames(df)

df  %>% filter(Supported_Enrichments!='C8, MWCO, PAGE, PCP') -> df
# Out:
#   Protein
# 1 PB.1000.1:chr1:+|33|1855:374:440|iORF|CTG
# 2 PB.1001.3:chr1:-|9|2745:169:253|iORF|ACG
# 3 PB.1001.41:chr1:-|217|3689:2936:2990|noncoding|GTG
# 4 PB.10020.13:chr12:+|22|1011:465:531|noncoding|ATG
# 5 PB.10022.2:chr12:+|99|3182:1589:1652|dORF|ATG
# 6 PB.10023.4:chr12:+|128|3001:2235:2307|dORF|ATG
#   Seq                         Supported_Enrichments seq_length molecular_weight
# 1 MAVGGAGDVDQSLQQPHQQSI       PCP                   21         2166.328
# 2 MTGSPAPSSSPLGLGRSGAGTLPGSIN PCP                   27         2469.726
# 3 MSYRCLAGQQVGVGQTM           C8                    17         1829.129
# 4 MIADFIIKQFICIFWSLTLIL       PCP                   21         2529.152
# 5 MEFLQESYKVPNDTRKITSQ        C8                    20         2414.689
# 6 MFFKKVISSLGECQIHTLRIDFI     PCP                   23         2726.262
#   AA_A       AA_C       AA_D       AA_E       AA_F      ⋯ Tri_WWM Tri_WWR
# 1 0.09523810 0.00000000 0.09523810 0.00000000 0.0000000 ⋯ 0       0
# 2 0.07407407 0.00000000 0.00000000 0.00000000 0.0000000 ⋯ 0       0
# 3 0.05882353 0.05882353 0.00000000 0.00000000 0.0000000 ⋯ 0       0
# 4 0.04761905 0.04761905 0.04761905 0.00000000 0.1428571 ⋯ 0       0
# 5 0.00000000 0.00000000 0.05000000 0.10000000 0.0500000 ⋯ 0       0
# 6 0.00000000 0.04347826 0.04347826 0.04347826 0.1304348 ⋯ 0       0
#   Tri_WCN Tri_WWC Tri_WDN Tri_CWN Tri_WMY isoelectric_point gravy
# 1 0       0       0       0       0       4.196048          -0.47142857
# 2 0       0       0       0       0       9.500077          -0.05925926
# 3 0       0       0       0       0       7.975271           0.07647059
# 4 0       0       0       0       0       5.585193           1.89047619
# 5 0       0       0       0       0       5.937367          -1.10000000
# 6 0       0       0       0       0       7.977656           0.60434783
#   charge_pH7
# 1 -2.4102296
# 2  0.5003447
# 3  0.4894447
# 4 -0.5094245
# 5 -0.4959106
# 6  0.5795511
#    [1] "Protein"               "Seq"                   "Supported_Enrichments"
#    [4] "seq_length"            "molecular_weight"      "AA_A"
#    [7] "AA_C"                  "AA_D"                  "AA_E"
#   [10] "AA_F"                  "AA_G"                  "AA_H"
#   [13] "AA_I"                  "AA_K"                  "AA_L"
#   [16] "AA_M"                  "AA_N"                  "AA_P"
#   [19] "AA_Q"                  "AA_R"                  "AA_S"
#   [22] "AA_T"                  "AA_V"                  "AA_W"
#   [25] "AA_Y"                  "Di_DQ"                 "Di_LQ"
#   [28] "Di_AV"                 "Di_GA"                 "Di_AG"
#   [31] "Di_QP"                 "Di_SI"                 "Di_SL"
#   [34] "Di_MA"                 "Di_DV"                 "Di_QS"
#   [37] "Di_GD"                 "Di_PH"                 "Di_VG"
#   [40] "Di_VD"                 "Di_GG"                 "Di_QQ"
#   [43] "Di_HQ"                 "Di_PS"                 "Di_MT"
#   [46] "Di_LP"                 "Di_PL"                 "Di_GL"
#   [49] "Di_GS"                 "Di_SP"                 "Di_PG"
#   [52] "Di_RS"                 "Di_TG"                 "Di_LG"
#   [55] "Di_GR"                 "Di_PA"                 "Di_GT"
#   [58] "Di_SS"                 "Di_AP"                 "Di_TL"
#   [61] "Di_IN"                 "Di_SG"                 "Di_MS"
#   [64] "Di_TM"                 "Di_SY"                 "Di_QV"
#   [67] "Di_RC"                 "Di_CL"                 "Di_GV"
#   [70] "Di_QT"                 "Di_GQ"                 "Di_YR"
#   [73] "Di_LA"                 "Di_CI"                 "Di_IF"
#   [76] "Di_LT"                 "Di_KQ"                 "Di_IA"
#   [79] "Di_IL"                 "Di_AD"                 "Di_DF"
#   [82] "Di_IK"                 "Di_WS"                 "Di_MI"
#   [85] "Di_FW"                 "Di_QF"                 "Di_FI"
#   [88] "Di_II"                 "Di_IC"                 "Di_LI"
#   [91] "Di_FL"                 "Di_ME"                 "Di_ES"
#   [94] "Di_VP"                 "Di_KI"                 "Di_YK"
#   [97] "Di_RK"                 "Di_QE"                 "Di_SQ"
#  [100] "Di_PN"                 "Di_DT"                 "Di_TS"
#  [103] "Di_EF"                 "Di_TR"                 "Di_ND"
#  [106] "Di_KV"                 "Di_IT"                 "Di_FF"
#  [109] "Di_CQ"                 "Di_GE"                 "Di_QI"
#  [112] "Di_HT"                 "Di_VI"                 "Di_IS"
#  [115] "Di_IH"                 "Di_LR"                 "Di_RI"
#  [118] "Di_FK"                 "Di_EC"                 "Di_MF"
#  [121] "Di_ID"                 "Di_KK"                 "Di_SN"
#  [124] "Di_KY"                 "Di_KS"                 "Di_MK"
#  [127] "Di_LS"                 "Di_HC"                 "Di_CF"
#  [130] "Di_CC"                 "Di_SH"                 "Di_YC"
#  [133] "Di_NN"                 "Di_EM"                 "Di_NK"
#  [136] "Di_CA"                 "Di_AL"                 "Di_VR"
#  [139] "Di_FR"                 "Di_YL"                 "Di_LV"
#  [142] "Di_DD"                 "Di_AQ"                 "Di_CN"
#  [145] "Di_QK"                 "Di_DN"                 "Di_VN"
#  [148] "Di_TY"                 "Di_LM"                 "Di_PK"
#  [151] "Di_AN"                 "Di_SE"                 "Di_VL"
#  [154] "Di_TV"                 "Di_DI"                 "Di_WK"
#  [157] "Di_TD"                 "Di_ST"                 "Di_VV"
#  [160] "Di_NL"                 "Di_YV"                 "Di_DY"
#  [163] "Di_VF"                 "Di_VT"                 "Di_GK"
#  [166] "Di_IV"                 "Di_NQ"                 "Di_LK"
#  [169] "Di_KM"                 "Di_TA"                 "Di_DK"
#  [172] "Di_GI"                 "Di_MM"                 "Di_EN"
#  [175] "Di_VA"                 "Di_GC"                 "Di_QH"
#  [178] "Di_RQ"                 "Di_HG"                 "Di_VK"
#  [181] "Di_VS"                 "Di_MY"                 "Di_KH"
#  [184] "Di_GW"                 "Di_HR"                 "Di_EV"
#  [187] "Di_WD"                 "Di_EK"                 "Di_YS"
#  [190] "Di_DL"                 "Di_SV"                 "Di_NP"
#  [193] "Di_DS"                 "Di_YE"                 "Di_EG"
#  [196] "Di_DE"                 "Di_RN"                 "Di_KF"
#  [199] "Di_DC"                 "Di_CH"                 "Di_WI"
#  [202] "Di_WA"                 "Di_GY"                 "Di_KN"
#  [205] "Di_SR"                 "Di_AI"                 "Di_EE"
#  [208] "Di_PD"                 "Di_SM"                 "Di_NA"
#  [211] "Di_EH"                 "Di_AT"                 "Di_LW"
#  [214] "Di_VW"                 "Di_SC"                 "Di_KE"
#  [217] "Di_RF"                 "Di_PE"                 "Di_RV"
#  [220] "Di_KG"                 "Di_MD"                 "Di_AY"
#  [223] "Di_TN"                 "Di_IE"                 "Di_IG"
#  [226] "Di_AE"                 "Di_LE"                 "Di_LN"
#  [229] "Di_VQ"                 "Di_PC"                 "Di_MV"
#  [232] "Di_RL"                 "Di_PQ"                 "Di_QL"
#  [235] "Di_ED"                 "Di_AC"                 "Di_YT"
#  [238] "Di_EL"                 "Di_LF"                 "Di_YG"
#  [241] "Di_MG"                 "Di_HP"                 "Di_KD"
#  [244] "Di_NS"                 "Di_GM"                 "Di_RY"
#  [247] "Di_VH"                 "Di_SK"                 "Di_SA"
#  [250] "Di_NW"                 "Di_KL"                 "Di_LD"
#  [253] "Di_NV"                 "Di_PV"                 "Di_QR"
#  [256] "Di_TP"                 "Di_ML"                 "Di_IP"
#  [259] "Di_VE"                 "Di_AR"                 "Di_NE"
#  [262] "Di_EA"                 "Di_TW"                 "Di_RG"
#  [265] "Di_HK"                 "Di_IQ"                 "Di_CT"
#  [268] "Di_RE"                 "Di_KC"                 "Di_DP"
#  [271] "Di_KA"                 "Di_QC"                 "Di_RD"
#  [274] "Di_AH"                 "Di_CV"                 "Di_HA"
#  [277] "Di_TT"                 "Di_TE"                 "Di_FD"
#  [280] "Di_ER"                 "Di_DH"                 "Di_LC"
#  [283] "Di_CE"                 "Di_EQ"                 "Di_LH"
#  [286] "Di_CD"                 "Di_FN"                 "Di_FQ"
#  [289] "Di_MH"                 "Di_TH"                 "Di_IR"
#  [292] "Di_HS"                 "Di_CG"                 "Di_LL"
#  [295] "Di_NC"                 "Di_FA"                 "Di_GF"
#  [298] "Di_AS"                 "Di_FS"                 "Di_RR"
#  [301] "Di_NF"                 "Di_GH"                 "Di_QN"
#  [304] "Di_FM"                 "Di_RH"                 "Di_TC"
#  [307] "Di_GP"                 "Di_KT"                 "Di_MR"
#  [310] "Di_DR"                 "Di_WP"                 "Di_FC"
#  [313] "Di_FT"                 "Di_PM"                 "Di_QY"
#  [316] "Di_RP"                 "Di_VY"                 "Di_QG"
#  [319] "Di_KR"                 "Di_FG"                 "Di_FP"
#  [322] "Di_CK"                 "Di_TK"                 "Di_YY"
#  [325] "Di_YF"                 "Di_CS"                 "Di_EI"
#  [328] "Di_WG"                 "Di_KW"                 "Di_HW"
#  [331] "Di_WE"                 "Di_EY"                 "Di_DA"
#  [334] "Di_YD"                 "Di_HL"                 "Di_PP"
#  [337] "Di_CR"                 "Di_AW"                 "Di_TF"
#  [340] "Di_GN"                 "Di_HF"                 "Di_SW"
#  [343] "Di_NI"                 "Di_AK"                 "Di_AA"
#  [346] "Di_DG"                 "Di_FV"                 "Di_PR"
#  [349] "Di_VM"                 "Di_DM"                 "Di_HV"
#  [352] "Di_EP"                 "Di_HE"                 "Di_KP"
#  [355] "Di_SD"                 "Di_SF"                 "Di_AF"
#  [358] "Di_HD"                 "Di_LY"                 "Di_NY"
#  [361] "Di_RW"                 "Di_WV"                 "Di_WR"
#  [364] "Di_PI"                 "Di_QA"                 "Di_FY"
#  [367] "Di_VC"                 "Di_YI"                 "Di_HN"
#  [370] "Di_YH"                 "Di_HI"                 "Di_IY"
#  [373] "Di_PT"                 "Di_DW"                 "Di_RA"
#  [376] "Di_QD"                 "Di_NG"                 "Di_EW"
#  [379] "Di_CW"                 "Di_NR"                 "Di_PW"
#  [382] "Di_FH"                 "Di_CY"                 "Di_NT"
#  [385] "Di_MN"                 "Di_AM"                 "Di_WQ"
#  [388] "Di_WF"                 "Di_ET"                 "Di_WL"
#  [391] "Di_MP"                 "Di_HH"                 "Di_HM"
#  [394] "Di_FE"                 "Di_QM"                 "Di_TQ"
#  [397] "Di_YN"                 "Di_RT"                 "Di_TI"
#  [400] "Di_IW"                 "Di_NM"                 "Di_YQ"
#  [403] "Di_MC"                 "Di_YP"                 "Di_PY"
#  [406] "Di_HY"                 "Di_MQ"                 "Di_IM"
#  [409] "Di_PF"                 "Di_YM"                 "Di_YA"
#  [412] "Di_CP"                 "Di_WT"                 "Di_RM"
#  [415] "Di_WN"                 "Di_CM"                 "Di_WM"
#  [418] "Di_WH"                 "Di_QW"                 "Di_NH"
#  [421] "Di_MW"                 "Di_YW"                 "Di_WW"
#  [424] "Di_WY"                 "Di_WC"                 "Tri_GAG"
#  [427] "Tri_VGG"               "Tri_QSL"               "Tri_HQQ"
#  [430] "Tri_AVG"               "Tri_QPH"               "Tri_MAV"
#  [433] "Tri_QQS"               "Tri_GDV"               "Tri_QSI"
#  [436] "Tri_DVD"               "Tri_QQP"               "Tri_GGA"
#  [439] "Tri_AGD"               "Tri_PHQ"               "Tri_DQS"
#  [442] "Tri_LQQ"               "Tri_SLQ"               "Tri_VDQ"
#  [445] "Tri_TGS"               "Tri_GSP"               "Tri_TLP"
#  [448] "Tri_SIN"               "Tri_GSI"               "Tri_RSG"
#  [451] "Tri_APS"               "Tri_GTL"               "Tri_PLG"
#  [454] "Tri_PAP"               "Tri_LGL"               "Tri_SPA"
#  [457] "Tri_SSS"               "Tri_SSP"               "Tri_LPG"
#  [460] "Tri_SGA"               "Tri_AGT"               "Tri_SPL"
#  [463] "Tri_MTG"               "Tri_GRS"               "Tri_PGS"
#  [466] "Tri_GLG"               "Tri_PSS"               "Tri_LGR"
#  [469] "Tri_QQV"               "Tri_MSY"               "Tri_GQT"
#  [472] "Tri_VGQ"               "Tri_AGQ"               "Tri_LAG"
#  [475] "Tri_VGV"               "Tri_QTM"               "Tri_SYR"
#  [478] "Tri_CLA"               "Tri_YRC"               "Tri_RCL"
#  [481] "Tri_GVG"               "Tri_GQQ"               "Tri_QVG"
#  [484] "Tri_WSL"               "Tri_FIC"               "Tri_IKQ"
#  [487] "Tri_CIF"               "Tri_TLI"               "Tri_IFW"
#  [490] "Tri_FWS"               "Tri_ADF"               "Tri_QFI"
#  [493] "Tri_IIK"               "Tri_IAD"               "Tri_LIL"
#  [496] "Tri_MIA"               "Tri_KQF"               "Tri_FII"
#  [499] "Tri_DFI"               "Tri_LTL"               "Tri_ICI"
#  [502] "Tri_SLT"               "Tri_DTR"               "Tri_YKV"
#  [505] "Tri_KIT"               "Tri_QES"               "Tri_VPN"
#  [508] "Tri_TSQ"               "Tri_LQE"               "Tri_MEF"
#  [511] "Tri_ESY"               "Tri_KVP"               "Tri_TRK"
#  [514] "Tri_EFL"               "Tri_FLQ"               "Tri_RKI"
#  [517] "Tri_ITS"               "Tri_SYK"               "Tri_PND"
#  [520] "Tri_NDT"               "Tri_CQI"               "Tri_SSL"
#  [523] "Tri_GEC"               "Tri_ISS"               "Tri_SLG"
#  [526] "Tri_LRI"               "Tri_IHT"               "Tri_LGE"
#  [529] "Tri_MFF"               "Tri_FFK"               "Tri_FKK"
#  [532] "Tri_KVI"               "Tri_IDF"               "Tri_KKV"
#  [535] "Tri_QIH"               "Tri_VIS"               "Tri_TLR"
#  [538] "Tri_HTL"               "Tri_RID"               "Tri_ECQ"
#  [541] "Tri_LSN"               "Tri_SHC"               "Tri_CFK"
#  [544] "Tri_KKS"               "Tri_KSH"               "Tri_CCF"
#  [547] "Tri_ILS"               "Tri_QII"               "Tri_IIL"
#  [550] "Tri_SNN"               "Tri_KYC"               "Tri_MKY"
#  [553] "Tri_HCQ"               "Tri_YCC"               "Tri_EEA"
#  [556] "Tri_EKL"               "Tri_MAC"               "Tri_ILT"
#  [559] "Tri_VLE"               "Tri_NSK"               "Tri_HPV"
#  [562] "Tri_VDV"               "Tri_SPD"               "Tri_VFL"
#  [565] "Tri_SLA"               "Tri_TAG"               "Tri_NVN"
#  [568] "Tri_PVA"               "Tri_GDS"               "Tri_KHR"
#  [571] "Tri_VIG"               "Tri_FLS"               "Tri_ADK"
#  [574] "Tri_KGY"               "Tri_RYL"               "Tri_TPK"
#  [577] "Tri_CII"               "Tri_KGM"               "Tri_NLS"
#  [580] "Tri_TVV"               "Tri_ARG"               "Tri_GSL"
#  [583] "Tri_VAV"               "Tri_VKG"               "Tri_SIL"
#  [586] "Tri_NAR"               "Tri_GVS"               "Tri_KYS"
#  [589] "Tri_KIV"               "Tri_NDS"               "Tri_DIQ"
#  [592] "Tri_VFK"               "Tri_LTS"               "Tri_INQ"
#  [595] "Tri_ADE"               "Tri_DLQ"               "Tri_LMA"
#  [598] "Tri_LIA"               "Tri_GLS"               "Tri_SSV"
#  [601] "Tri_KLK"               "Tri_LNP"               "Tri_NWA"
#  [604] "Tri_LQT"               "Tri_GWI"               "Tri_VES"
#  [607] "Tri_DCI"               "Tri_MLK"               "Tri_DIL"
#  [610] "Tri_NNK"               "Tri_TSV"               "Tri_VVE"
#  [613] "Tri_LPK"               "Tri_ACA"               "Tri_QIV"
#  [616] "Tri_LQH"               "Tri_VVG"               "Tri_SGC"
#  [619] "Tri_YVT"               "Tri_LSR"               "Tri_RFR"
#  [622] "Tri_GEH"               "Tri_VGM"               "Tri_DSS"
#  [625] "Tri_SRI"               "Tri_ATL"               "Tri_RNV"
#  [628] "Tri_GEM"               "Tri_NKI"               "Tri_SVT"
#  [631] "Tri_IVV"               "Tri_SVI"               "Tri_QLK"
#  [634] "Tri_SKI"               "Tri_DDE"               "Tri_PVS"
#  [637] "Tri_EVA"               "Tri_SRL"               "Tri_LKK"
#  [640] "Tri_IVA"               "Tri_NPE"               "Tri_IPQ"
#  [643] "Tri_YEV"               "Tri_EVI"               "Tri_IIP"
#  [646] "Tri_LKD"               "Tri_ELN"               "Tri_GVR"
#  [649] "Tri_GIH"               "Tri_KDL"               "Tri_EMM"
#  [652] "Tri_III"               "Tri_VIK"               "Tri_LGK"
#  [655] "Tri_MDL"               "Tri_ELA"               "Tri_IGL"
#  [658] "Tri_KLG"               "Tri_AEE"               "Tri_KMV"
#  [661] "Tri_ESM"               "Tri_RVI"               "Tri_VVV"
#  [664] "Tri_IQK"               "Tri_LWD"               "Tri_GQV"
#  [667] "Tri_KSA"               "Tri_NEV"               "Tri_HKM"
#  [670] "Tri_TDN"               "Tri_VAQ"               "Tri_TLW"
#  [673] "Tri_LSG"               "Tri_VVS"               "Tri_RQQ"
#  [676] "Tri_DND"               "Tri_GMA"               "Tri_GVN"
#  [679] "Tri_EVH"               "Tri_SLP"               "Tri_RLN"
#  [682] "Tri_WIL"               "Tri_APV"               "Tri_LVD"
#  [685] "Tri_PQI"               "Tri_NQK"               "Tri_YLM"
#  [688] "Tri_SVA"               "Tri_AGV"               "Tri_LNA"
#  [691] "Tri_NVF"               "Tri_LKE"               "Tri_LKN"
#  [694] "Tri_DSA"               "Tri_LKG"               "Tri_KLI"
#  [697] "Tri_YTN"               "Tri_DLI"               "Tri_MYG"
#  [700] "Tri_VKY"               "Tri_VAD"               "Tri_HGD"
#  [703] "Tri_GIE"               "Tri_VDI"               "Tri_IHP"
#  [706] "Tri_LED"               "Tri_DKD"               "Tri_AIG"
#  [709] "Tri_WDI"               "Tri_PEM"               "Tri_LAL"
#  [712] "Tri_QQE"               "Tri_KDD"               "Tri_IES"
#  [715] "Tri_AVW"               "Tri_CAI"               "Tri_GYT"
#  [718] "Tri_GMY"               "Tri_ADT"               "Tri_CIL"
#  [721] "Tri_QRN"               "Tri_TWK"               "Tri_SCH"
#  [724] "Tri_PCI"               "Tri_MAE"               "Tri_TMV"
#  [727] "Tri_IGS"               "Tri_LAD"               "Tri_LPC"
#  [730] "Tri_VTW"               "Tri_ANS"               "Tri_VNV"
#  [733] "Tri_VSL"               "Tri_QTP"               "Tri_KEK"
#  [736] "Tri_NWK"               "Tri_ATV"               "Tri_EEE"
#  [739] "Tri_QHG"               "Tri_TAN"               "Tri_HGS"
#  [742] "Tri_VIN"               "Tri_DKL"               "Tri_VVT"
#  [745] "Tri_CHG"               "Tri_PVD"               "Tri_RGL"
#  [748] "Tri_LFL"               "Tri_GLP"               "Tri_EHG"
#  [751] "Tri_VST"               "Tri_LGI"               "Tri_VAG"
#  [754] "Tri_IKL"               "Tri_ESR"               "Tri_RIH"
#  [757] "Tri_KEV"               "Tri_ARF"               "Tri_WKE"
#  [760] "Tri_LIE"               "Tri_SGV"               "Tri_NVA"
#  [763] "Tri_DVL"               "Tri_SNP"               "Tri_LDS"
#  [766] "Tri_SAY"               "Tri_EDK"               "Tri_ENW"
#  [769] "Tri_ILN"               "Tri_DYS"               "Tri_HPS"
#  [772] "Tri_QKD"               "Tri_ENE"               "Tri_KFI"
#  [775] "Tri_AEK"               "Tri_QKL"               "Tri_TNW"
#  [778] "Tri_TLK"               "Tri_VAE"               "Tri_PDC"
#  [781] "Tri_GTD"               "Tri_LSV"               "Tri_SLF"
#  [784] "Tri_ESA"               "Tri_DSE"               "Tri_MGT"
#  [787] "Tri_CNL"               "Tri_WKL"               "Tri_DEL"
#  [790] "Tri_GLT"               "Tri_MAT"               "Tri_VRQ"
#  [793] "Tri_NLV"               "Tri_DTL"               "Tri_IVK"
#  [796] "Tri_GKS"               "Tri_DEV"               "Tri_EVF"
#  [799] "Tri_LNL"               "Tri_VHK"               "Tri_VSN"
#  [802] "Tri_VWS"               "Tri_NPV"               "Tri_PKI"
#  [805] "Tri_YGI"               "Tri_ISI"               "Tri_KGE"
#  [808] "Tri_SML"               "Tri_EAT"               "Tri_VTA"
#  [811] "Tri_HGW"               "Tri_QEG"               "Tri_SGL"
#  [814] "Tri_VQR"               "Tri_HRV"               "Tri_PKH"
#  [817] "Tri_ILG"               "Tri_LSL"               "Tri_TYV"
#  [820] "Tri_YSP"               "Tri_IEN"               "Tri_FKF"
#  [823] "Tri_KLS"               "Tri_DLK"               "Tri_NLD"
#  [826] "Tri_WSG"               "Tri_YSV"               "Tri_WAI"
#  [829] "Tri_TVP"               "Tri_MMD"               "Tri_EGE"
#  [832] "Tri_STM"               "Tri_MVV"               "Tri_SEN"
#  [835] "Tri_LVQ"               "Tri_GSG"               "Tri_ADL"
#  [838] "Tri_AIS"               "Tri_SAR"               "Tri_MVK"
#  [841] "Tri_AQL"               "Tri_SAD"               "Tri_AYE"
#  [844] "Tri_GCN"               "Tri_ITV"               "Tri_GES"
#  [847] "Tri_KDY"               "Tri_ALV"               "Tri_EMG"
#  [850] "Tri_SSC"               "Tri_FRY"               "Tri_LTY"
#  [853] "Tri_KSL"               "Tri_QEL"               "Tri_IIV"
#  [856] "Tri_KNL"               "Tri_IAP"               "Tri_PNN"
#  [859] "Tri_KAR"               "Tri_TEE"               "Tri_SSR"
#  [862] "Tri_RLE"               "Tri_DCT"               "Tri_LCD"
#  [865] "Tri_EQK"               "Tri_VSS"               "Tri_LFN"
#  [868] "Tri_TES"               "Tri_DER"               "Tri_FDF"
#  [871] "Tri_KCV"               "Tri_HTE"               "Tri_QLE"
#  [874] "Tri_LTE"               "Tri_CTE"               "Tri_PLT"
#  [877] "Tri_ESG"               "Tri_KML"               "Tri_HCV"
#  [880] "Tri_SGD"               "Tri_VAH"               "Tri_NLK"
#  [883] "Tri_EDC"               "Tri_QKM"               "Tri_CVA"
#  [886] "Tri_MLT"               "Tri_LTT"               "Tri_LEK"
#  [889] "Tri_VDP"               "Tri_ERV"               "Tri_VRE"
#  [892] "Tri_DPL"               "Tri_REQ"               "Tri_FNN"
#  [895] "Tri_RSH"               "Tri_ARD"               "Tri_HKL"
#  [898] "Tri_EDE"               "Tri_TVR"               "Tri_RDH"
#  [901] "Tri_TTV"               "Tri_ELF"               "Tri_AHK"
#  [904] "Tri_CVK"               "Tri_DEQ"               "Tri_SRS"
#  [907] "Tri_VKA"               "Tri_CDE"               "Tri_EQL"
#  [910] "Tri_DPE"               "Tri_RER"               "Tri_RVS"
#  [913] "Tri_CEQ"               "Tri_EEL"               "Tri_DHC"
#  [916] "Tri_FLH"               "Tri_KLF"               "Tri_MGL"
#  [919] "Tri_HAR"               "Tri_GLE"               "Tri_EQC"
#  [922] "Tri_LEL"               "Tri_ELC"               "Tri_DFL"
#  [925] "Tri_LHA"               "Tri_NNL"               "Tri_ERL"
#  [928] "Tri_EED"               "Tri_ELV"               "Tri_QCE"
#  [931] "Tri_GDP"               "Tri_PEE"               "Tri_LFD"
#  [934] "Tri_ARE"               "Tri_SHT"               "Tri_EKC"
#  [937] "Tri_AVL"               "Tri_MHS"               "Tri_GFQ"
#  [940] "Tri_AIR"               "Tri_HSR"               "Tri_IRS"
#  [943] "Tri_QLT"               "Tri_RVF"               "Tri_AGF"
#  [946] "Tri_SAI"               "Tri_QFS"               "Tri_LQF"
#  [949] "Tri_SCL"               "Tri_SNC"               "Tri_RFA"
#  [952] "Tri_SRR"               "Tri_GAS"               "Tri_FAV"
#  [955] "Tri_CLH"               "Tri_LLS"               "Tri_PVR"
#  [958] "Tri_CGA"               "Tri_VLL"               "Tri_RRF"
#  [961] "Tri_NCG"               "Tri_RSC"               "Tri_LHP"
#  [964] "Tri_VRV"               "Tri_RSR"               "Tri_ASA"
#  [967] "Tri_FQL"               "Tri_FSA"               "Tri_LTH"
#  [970] "Tri_SAG"               "Tri_KER"               "Tri_SIR"
#  [973] "Tri_FTF"               "Tri_PCT"               "Tri_HRY"
#  [976] "Tri_VIP"               "Tri_LLP"               "Tri_PRR"
#  [979] "Tri_DRV"               "Tri_VED"               "Tri_AAP"
#  [982] "Tri_LVN"               "Tri_NLA"               "Tri_CRN"
#  [985] "Tri_PAR"               "Tri_KFP"               "Tri_DIS"
#  [988] "Tri_ISH"               "Tri_LAN"               "Tri_VLV"
#  [991] "Tri_VQV"               "Tri_ANQ"               "Tri_QVR"
#  [994] "Tri_TFD"               "Tri_YFC"               "Tri_LEQ"
#  [997] "Tri_AYS"               "Tri_CTT"               "Tri_WDG"
# [1000] "Tri_LCA"               "Tri_NNF"               "Tri_FKR"
# [1003] "Tri_CFT"               "Tri_CKM"               "Tri_LKR"
# [1006] "Tri_TLA"               "Tri_DHV"               "Tri_AGL"
# [1009] "Tri_MEY"               "Tri_SVQ"               "Tri_RVT"
# [1012] "Tri_DIV"               "Tri_VRL"               "Tri_QSE"
# [1015] "Tri_LQV"               "Tri_ELL"               "Tri_FFS"
# [1018] "Tri_YST"               "Tri_RDG"               "Tri_MAN"
# [1021] "Tri_PSI"               "Tri_QKI"               "Tri_TSW"
# [1024] "Tri_NFA"               "Tri_PVL"               "Tri_AAG"
# [1027] "Tri_GQS"               "Tri_RKW"               "Tri_REL"
# [1030] "Tri_DLA"               "Tri_CFF"               "Tri_DLT"
# [1033] "Tri_NDL"               "Tri_PAS"               "Tri_TCS"
# [1036] "Tri_SEG"               "Tri_DGN"               "Tri_VME"
# [1039] "Tri_TDR"               "Tri_QLS"               "Tri_GKT"
# [1042] "Tri_DLC"               "Tri_WPS"               "Tri_ARL"
# [1045] "Tri_PSP"               "Tri_LLA"               "Tri_CCR"
# [1048] "Tri_KKW"               "Tri_VTS"               "Tri_MYF"
# [1051] "Tri_RLQ"               "Tri_CSP"               "Tri_QNE"
# [1054] "Tri_RCF"               "Tri_YGA"               "Tri_ATE"
# [1057] "Tri_LQN"               "Tri_KLE"               "Tri_AND"
# [1060] "Tri_LQP"               "Tri_LMD"               "Tri_FCK"
# [1063] "Tri_MDA"               "Tri_KWA"               "Tri_ELE"
# [1066] "Tri_EPK"               "Tri_KKK"               "Tri_SWA"
# [1069] "Tri_LEG"               "Tri_LVI"               "Tri_PSR"
# [1072] "Tri_KRV"               "Tri_AAT"               "Tri_ILH"
# [1075] "Tri_NFD"               "Tri_HFR"               "Tri_VLD"
# [1078] "Tri_LSA"               "Tri_QTG"               "Tri_CSL"
# [1081] "Tri_RIA"               "Tri_TKP"               "Tri_YSI"
# [1084] "Tri_RNL"               "Tri_MDT"               "Tri_MAA"
# [1087] "Tri_SIQ"               "Tri_ASL"               "Tri_SRK"
# [1090] "Tri_EGD"               "Tri_HWE"               "Tri_DLW"
# [1093] "Tri_GGH"               "Tri_KRS"               "Tri_ISR"
# [1096] "Tri_TGC"               "Tri_DRG"               "Tri_SEQ"
# [1099] "Tri_RVD"               "Tri_GPM"               "Tri_RRV"
# [1102] "Tri_NQY"               "Tri_ARP"               "Tri_IEL"
# [1105] "Tri_SRF"               "Tri_NQV"               "Tri_SLL"
# [1108] "Tri_RHR"               "Tri_SHL"               "Tri_QVE"
# [1111] "Tri_ANF"               "Tri_VVQ"               "Tri_SHW"
# [1114] "Tri_KMR"               "Tri_DTY"               "Tri_NLM"
# [1117] "Tri_FPA"               "Tri_IFK"               "Tri_VDL"
# [1120] "Tri_DAA"               "Tri_IPN"               "Tri_CAA"
# [1123] "Tri_YDR"               "Tri_THF"               "Tri_QSA"
# [1126] "Tri_WEL"               "Tri_KDF"               "Tri_NEY"
# [1129] "Tri_YYL"               "Tri_QPG"               "Tri_HLQ"
# [1132] "Tri_ASW"               "Tri_SYV"               "Tri_AAW"
# [1135] "Tri_TYD"               "Tri_FVN"               "Tri_LLQ"
# [1138] "Tri_LSH"               "Tri_APG"               "Tri_RGV"
# [1141] "Tri_VPC"               "Tri_RVL"               "Tri_SWD"
# [1144] "Tri_ERQ"               "Tri_GHV"               "Tri_WDH"
# [1147] "Tri_RGD"               "Tri_RQI"               "Tri_LHE"
# [1150] "Tri_ACS"               "Tri_DRH"               "Tri_PPA"
# [1153] "Tri_GLQ"               "Tri_EYV"               "Tri_FRR"
# [1156] "Tri_VQL"               "Tri_QIL"               "Tri_VPE"
# [1159] "Tri_GNQ"               "Tri_IRD"               "Tri_PGD"
# [1162] "Tri_FAA"               "Tri_DVP"               "Tri_DGR"
# [1165] "Tri_SLS"               "Tri_FMD"               "Tri_FGP"
# [1168] "Tri_AKD"               "Tri_NNI"               "Tri_AAL"
# [1171] "Tri_NLR"               "Tri_LGV"               "Tri_WAA"
# [1174] "Tri_FPP"               "Tri_ALL"               "Tri_PKF"
# [1177] "Tri_DMA"               "Tri_HSL"               "Tri_LAA"
# [1180] "Tri_SCQ"               "Tri_EEN"               "Tri_PAV"
# [1183] "Tri_MRR"               "Tri_VFM"               "Tri_VNN"
# [1186] "Tri_RLA"               "Tri_VQF"               "Tri_IVL"
# [1189] "Tri_VQG"               "Tri_DFV"               "Tri_TFC"
# [1192] "Tri_VLA"               "Tri_LDL"               "Tri_KIL"
# [1195] "Tri_QGA"               "Tri_SPN"               "Tri_PNL"
# [1198] "Tri_AAN"               "Tri_LQS"               "Tri_GGQ"
# [1201] "Tri_HEE"               "Tri_LSP"               "Tri_KKE"
# [1204] "Tri_NFG"               "Tri_PMY"               "Tri_ALQ"
# [1207] "Tri_FSS"               "Tri_IRV"               "Tri_QKY"
# [1210] "Tri_GDL"               "Tri_AWD"               "Tri_DLS"
# [1213] "Tri_LPV"               "Tri_GEL"               "Tri_GVM"
# [1216] "Tri_QLL"               "Tri_GLL"               "Tri_QYS"
# [1219] "Tri_KWG"               "Tri_HVV"               "Tri_QFG"
# [1222] "Tri_ILP"               "Tri_WGE"               "Tri_KTL"
# [1225] "Tri_KYG"               "Tri_LQK"               "Tri_VGE"
# [1228] "Tri_LRG"               "Tri_GRK"               "Tri_LRC"
# [1231] "Tri_ATK"               "Tri_YVP"               "Tri_SLH"
# [1234] "Tri_RFP"               "Tri_LLK"               "Tri_RRL"
# [1237] "Tri_MAY"               "Tri_NIF"               "Tri_TEP"
# [1240] "Tri_VNE"               "Tri_EDL"               "Tri_VPR"
# [1243] "Tri_AKL"               "Tri_RYK"               "Tri_QVQ"
# [1246] "Tri_GAI"               "Tri_IAR"               "Tri_AVR"
# [1249] "Tri_FGD"               "Tri_EEI"               "Tri_ALT"
# [1252] "Tri_LAT"               "Tri_AAS"               "Tri_RRH"
# [1255] "Tri_VSA"               "Tri_FCF"               "Tri_ALG"
# [1258] "Tri_GCC"               "Tri_IQV"               "Tri_RHS"
# [1261] "Tri_WAC"               "Tri_YKK"               "Tri_RPG"
# [1264] "Tri_FDR"               "Tri_GGK"               "Tri_LSE"
# [1267] "Tri_HSY"               "Tri_PGG"               "Tri_VYS"
# [1270] "Tri_VLQ"               "Tri_LHS"               "Tri_RLT"
# [1273] "Tri_LWP"               "Tri_EYY"               "Tri_QNF"
# [1276] "Tri_YVV"               "Tri_SAA"               "Tri_GDI"
# [1279] "Tri_EIR"               "Tri_SAK"               "Tri_RKK"
# [1282] "Tri_DTF"               "Tri_CQV"               "Tri_GAL"
# [1285] "Tri_ELQ"               "Tri_AIE"               "Tri_KPG"
# [1288] "Tri_FDM"               "Tri_EAI"               "Tri_ENN"
# [1291] "Tri_SPS"               "Tri_STC"               "Tri_NEA"
# [1294] "Tri_GDT"               "Tri_VVY"               "Tri_HVS"
# [1297] "Tri_EGG"               "Tri_TTD"               "Tri_PIA"
# [1300] "Tri_VSK"               "Tri_RRQ"               "Tri_LLV"
# [1303] "Tri_LKL"               "Tri_GWV"               "Tri_KLD"
# [1306] "Tri_QTL"               "Tri_ATS"               "Tri_TAQ"
# [1309] "Tri_ERA"               "Tri_NID"               "Tri_EKG"
# [1312] "Tri_ILA"               "Tri_CST"               "Tri_SKQ"
# [1315] "Tri_TDH"               "Tri_LQG"               "Tri_CSK"
# [1318] "Tri_FRW"               "Tri_HPT"               "Tri_RHQ"
# [1321] "Tri_HSV"               "Tri_RGA"               "Tri_DEE"
# [1324] "Tri_QAT"               "Tri_LQR"               "Tri_YVS"
# [1327] "Tri_EHI"               "Tri_NGH"               "Tri_HLA"
# [1330] "Tri_EGY"               "Tri_YEN"               "Tri_VWV"
# [1333] "Tri_LIG"               "Tri_VGN"               "Tri_ISE"
# [1336] "Tri_QVH"               "Tri_PLN"               "Tri_AKR"
# [1339] "Tri_GQG"               "Tri_NIQ"               "Tri_MEK"
# [1342] "Tri_VGL"               "Tri_RPP"               "Tri_KSG"
# [1345] "Tri_DSV"               "Tri_FAK"               "Tri_AYY"
# [1348] "Tri_WVL"               "Tri_KPP"               "Tri_PLI"
# [1351] "Tri_SLK"               "Tri_PCL"               "Tri_SVE"
# [1354] "Tri_SKG"               "Tri_KNI"               "Tri_GVP"
# [1357] "Tri_FLN"               "Tri_DID"               "Tri_IKH"
# [1360] "Tri_REE"               "Tri_SFY"               "Tri_KGI"
# [1363] "Tri_GAQ"               "Tri_VSV"               "Tri_RQD"
# [1366] "Tri_IGI"               "Tri_EVT"               "Tri_RPR"
# [1369] "Tri_RKE"               "Tri_KHL"               "Tri_QSV"
# [1372] "Tri_TDL"               "Tri_DCK"               "Tri_EII"
# [1375] "Tri_SVF"               "Tri_EKP"               "Tri_FSV"
# [1378] "Tri_PPH"               "Tri_CKC"               "Tri_TSL"
# [1381] "Tri_AEH"               "Tri_IDW"               "Tri_GNE"
# [1384] "Tri_VGY"               "Tri_DWD"               "Tri_NGS"
# [1387] "Tri_IDV"               "Tri_EPL"               "Tri_QKA"
# [1390] "Tri_LAR"               "Tri_VAK"               "Tri_VPL"
# [1393] "Tri_EEC"               "Tri_GIS"               "Tri_SVD"
# [1396] "Tri_KDA"               "Tri_IYV"               "Tri_SVW"
# [1399] "Tri_GVE"               "Tri_SSE"               "Tri_KVA"
# [1402] "Tri_WPI"               "Tri_AKQ"               "Tri_HRR"
# [1405] "Tri_DGE"               "Tri_GYI"               "Tri_HNE"
# [1408] "Tri_ALI"               "Tri_HIY"               "Tri_WRK"
# [1411] "Tri_AVV"               "Tri_EIE"               "Tri_RRS"
# [1414] "Tri_PKL"               "Tri_ISL"               "Tri_GGR"
# [1417] "Tri_CLL"               "Tri_EWR"               "Tri_VDE"
# [1420] "Tri_QDW"               "Tri_VLR"               "Tri_LVC"
# [1423] "Tri_NSR"               "Tri_AQV"               "Tri_FYF"
# [1426] "Tri_SYD"               "Tri_KME"               "Tri_NGG"
# [1429] "Tri_AII"               "Tri_RLI"               "Tri_ICL"
# [1432] "Tri_SEI"               "Tri_MRA"               "Tri_GYF"
# [1435] "Tri_LME"               "Tri_VSD"               "Tri_EVS"
# [1438] "Tri_GAP"               "Tri_FQS"               "Tri_VTE"
# [1441] "Tri_WVS"               "Tri_GSF"               "Tri_TNG"
# [1444] "Tri_HIC"               "Tri_EFA"               "Tri_AQK"
# [1447] "Tri_GNI"               "Tri_MEV"               "Tri_YDV"
# [1450] "Tri_SVS"               "Tri_FAE"               "Tri_YGY"
# [1453] "Tri_CWK"               "Tri_KLL"               "Tri_PAK"
# [1456] "Tri_NPR"               "Tri_EQR"               "Tri_SDK"
# [1459] "Tri_KRP"               "Tri_VFS"               "Tri_RAC"
# [1462] "Tri_LYE"               "Tri_TLS"               "Tri_LAV"
# [1465] "Tri_KGA"               "Tri_NYH"               "Tri_GRP"
# [1468] "Tri_APA"               "Tri_IQA"               "Tri_KQT"
# [1471] "Tri_CNG"               "Tri_RPS"               "Tri_CQK"
# [1474] "Tri_KLQ"               "Tri_STA"               "Tri_GYD"
# [1477] "Tri_DQK"               "Tri_HDE"               "Tri_YEM"
# [1480] "Tri_DEW"               "Tri_YDS"               "Tri_QFR"
# [1483] "Tri_VVR"               "Tri_AFQ"               "Tri_NPA"
# [1486] "Tri_LDA"               "Tri_ENV"               "Tri_IPL"
# [1489] "Tri_HQF"               "Tri_IEM"               "Tri_GCL"
# [1492] "Tri_LGN"               "Tri_REV"               "Tri_LLM"
# [1495] "Tri_IRE"               "Tri_NLN"               "Tri_ECL"
# [1498] "Tri_PTD"               "Tri_MGY"               "Tri_REF"
# [1501] "Tri_SVV"               "Tri_QKG"               "Tri_CLT"
# [1504] "Tri_DEI"               "Tri_AEQ"               "Tri_LCW"
# [1507] "Tri_EVD"               "Tri_KAV"               "Tri_KVN"
# [1510] "Tri_RNS"               "Tri_DHD"               "Tri_VEK"
# [1513] "Tri_SDE"               "Tri_PPK"               "Tri_EIK"
# [1516] "Tri_YHN"               "Tri_RHL"               "Tri_PAD"
# [1519] "Tri_KEM"               "Tri_QGR"               "Tri_RAE"
# [1522] "Tri_GAF"               "Tri_EIQ"               "Tri_YYE"
# [1525] "Tri_IIS"               "Tri_YFA"               "Tri_WSE"
# [1528] "Tri_PLK"               "Tri_ALD"               "Tri_LIS"
# [1531] "Tri_FGK"               "Tri_GKM"               "Tri_IIE"
# [1534] "Tri_KGV"               "Tri_ELY"               "Tri_FGA"
# [1537] "Tri_IVG"               "Tri_GLC"               "Tri_QKV"
# [1540] "Tri_STD"               "Tri_LTN"               "Tri_GRG"
# [1543] "Tri_GSK"               "Tri_ISY"               "Tri_RVG"
# [1546] "Tri_EHS"               "Tri_DAI"               "Tri_VCN"
# [1549] "Tri_SKD"               "Tri_SGI"               "Tri_PRG"
# [1552] "Tri_LRA"               "Tri_EEG"               "Tri_GYL"
# [1555] "Tri_KLA"               "Tri_RGR"               "Tri_KRH"
# [1558] "Tri_NIK"               "Tri_QRV"               "Tri_VVD"
# [1561] "Tri_VAY"               "Tri_HLI"               "Tri_YLG"
# [1564] "Tri_EMI"               "Tri_KMA"               "Tri_EMR"
# [1567] "Tri_MDS"               "Tri_GDQ"               "Tri_CNI"
# [1570] "Tri_DGC"               "Tri_QGG"               "Tri_DSG"
# [1573] "Tri_RSS"               "Tri_KDS"               "Tri_DVK"
# [1576] "Tri_VKD"               "Tri_CLK"               "Tri_PHL"
# [1579] "Tri_YFG"               "Tri_IAE"               "Tri_LDC"
# [1582] "Tri_RWS"               "Tri_RGG"               "Tri_AYL"
# [1585] "Tri_DAC"               "Tri_QKE"               "Tri_TSP"
# [1588] "Tri_LNY"               "Tri_EVR"               "Tri_STS"
# [1591] "Tri_IDG"               "Tri_VRR"               "Tri_SST"
# [1594] "Tri_ADA"               "Tri_EKV"               "Tri_SER"
# [1597] "Tri_GIP"               "Tri_RYG"               "Tri_DWP"
# [1600] "Tri_KCN"               "Tri_AEM"               "Tri_NSC"
# [1603] "Tri_LRY"               "Tri_GHI"               "Tri_VHR"
# [1606] "Tri_IGW"               "Tri_MIR"               "Tri_ICK"
# [1609] "Tri_ENG"               "Tri_YLQ"               "Tri_IEF"
# [1612] "Tri_SRG"               "Tri_RAA"               "Tri_YIC"
# [1615] "Tri_SEV"               "Tri_SPC"               "Tri_LSS"
# [1618] "Tri_GAA"               "Tri_IEV"               "Tri_KEI"
# [1621] "Tri_VSG"               "Tri_NNS"               "Tri_GGS"
# [1624] "Tri_SLD"               "Tri_GKE"               "Tri_FQR"
# [1627] "Tri_QRG"               "Tri_RVP"               "Tri_REG"
# [1630] "Tri_FLL"               "Tri_EEP"               "Tri_AGE"
# [1633] "Tri_EPG"               "Tri_VPA"               "Tri_GAR"
# [1636] "Tri_GEA"               "Tri_LRE"               "Tri_SSF"
# [1639] "Tri_PGA"               "Tri_GWG"               "Tri_PAG"
# [1642] "Tri_SFL"               "Tri_EGW"               "Tri_WGA"
# [1645] "Tri_LLR"               "Tri_ASS"               "Tri_EAE"
# [1648] "Tri_RAS"               "Tri_ARV"               "Tri_DPS"
# [1651] "Tri_GKR"               "Tri_RRE"               "Tri_MLQ"
# [1654] "Tri_QNR"               "Tri_LGD"               "Tri_AAA"
# [1657] "Tri_RLL"               "Tri_ALC"               "Tri_CAL"
# [1660] "Tri_RPW"               "Tri_PSA"               "Tri_QGK"
# [1663] "Tri_PWP"               "Tri_NRR"               "Tri_QIF"
# [1666] "Tri_QTF"               "Tri_NLI"               "Tri_ICN"
# [1669] "Tri_LID"               "Tri_SPQ"               "Tri_TFS"
# [1672] "Tri_IDS"               "Tri_VSF"               "Tri_SFQ"
# [1675] "Tri_MSV"               "Tri_QQT"               "Tri_IFF"
# [1678] "Tri_VIC"               "Tri_SFH"               "Tri_PQQ"
# [1681] "Tri_PTH"               "Tri_FQI"               "Tri_FPT"
# [1684] "Tri_FSF"               "Tri_FFP"               "Tri_FHV"
# [1687] "Tri_PEV"               "Tri_ANY"               "Tri_WDP"
# [1690] "Tri_VQD"               "Tri_LFT"               "Tri_RDE"
# [1693] "Tri_RCR"               "Tri_EDV"               "Tri_QLY"
# [1696] "Tri_LYC"               "Tri_FSL"               "Tri_VRI"
# [1699] "Tri_CTF"               "Tri_KTT"               "Tri_TDG"
# [1702] "Tri_SFF"               "Tri_MED"               "Tri_KSF"
# [1705] "Tri_LRP"               "Tri_RPH"               "Tri_QEV"
# [1708] "Tri_YVG"               "Tri_KHV"               "Tri_APQ"
# [1711] "Tri_GCY"               "Tri_NVT"               "Tri_YCT"
# [1714] "Tri_GSR"               "Tri_ITN"               "Tri_PQE"
# [1717] "Tri_EVP"               "Tri_LLL"               "Tri_EFI"
# [1720] "Tri_NGL"               "Tri_RIY"               "Tri_QLF"
# [1723] "Tri_CAP"               "Tri_GIT"               "Tri_EEV"
# [1726] "Tri_GCR"               "Tri_GCA"               "Tri_VKS"
# [1729] "Tri_DGI"               "Tri_TVQ"               "Tri_TME"
# [1732] "Tri_IYG"               "Tri_CKG"               "Tri_CYE"
# [1735] "Tri_QHL"               "Tri_FTD"               "Tri_FRV"
# [1738] "Tri_HVC"               "Tri_VPP"               "Tri_AIF"
# [1741] "Tri_YIH"               "Tri_KGK"               "Tri_EAL"
# ...
# [7822] "Tri_NYN"               "Tri_GKW"               "Tri_WYC"
# [7825] "Tri_GWN"               "Tri_HCK"               "Tri_NHR"
# [7828] "Tri_HCC"               "Tri_YNN"               "Tri_QFN"
# [7831] "Tri_NHY"               "Tri_DIN"               "Tri_LWW"
# [7834] "Tri_FNM"               "Tri_NMQ"               "Tri_WWA"
# [7837] "Tri_KYN"               "Tri_CGM"               "Tri_IMY"
# [7840] "Tri_QIM"               "Tri_NMD"               "Tri_IHK"
# [7843] "Tri_IIH"               "Tri_TMI"               "Tri_IKM"
# [7846] "Tri_EHW"               "Tri_LMN"               "Tri_HFK"
# [7849] "Tri_AQW"               "Tri_EWN"               "Tri_HCD"
# [7852] "Tri_WSM"               "Tri_TEC"               "Tri_LWE"
# [7855] "Tri_NEW"               "Tri_VHH"               "Tri_TNI"
# [7858] "Tri_RPY"               "Tri_NEH"               "Tri_CNF"
# [7861] "Tri_ECY"               "Tri_IWG"               "Tri_CYR"
# [7864] "Tri_YQD"               "Tri_WKR"               "Tri_DIP"
# [7867] "Tri_HCS"               "Tri_AHC"               "Tri_NFC"
# [7870] "Tri_CTC"               "Tri_MCA"               "Tri_AWQ"
# [7873] "Tri_IIC"               "Tri_LNH"               "Tri_KWP"
# [7876] "Tri_AMF"               "Tri_NHA"               "Tri_FCQ"
# [7879] "Tri_SEY"               "Tri_HMS"               "Tri_NGM"
# [7882] "Tri_FFQ"               "Tri_WQT"               "Tri_EYP"
# [7885] "Tri_WPK"               "Tri_NWQ"               "Tri_YNF"
# [7888] "Tri_CFQ"               "Tri_WYA"               "Tri_YAC"
# [7891] "Tri_WQK"               "Tri_SKM"               "Tri_YNY"
# [7894] "Tri_YWY"               "Tri_HNH"               "Tri_CMN"
# [7897] "Tri_CFY"               "Tri_GWH"               "Tri_WQA"
# [7900] "Tri_ANC"               "Tri_TWQ"               "Tri_WLW"
# [7903] "Tri_HCN"               "Tri_CFN"               "Tri_CEC"
# [7906] "Tri_NCD"               "Tri_VWP"               "Tri_WML"
# [7909] "Tri_LWM"               "Tri_YCI"               "Tri_EYC"
# [7912] "Tri_TND"               "Tri_ECM"               "Tri_MYT"
# [7915] "Tri_DHY"               "Tri_HLY"               "Tri_CMG"
# [7918] "Tri_KND"               "Tri_KHT"               "Tri_PNY"
# [7921] "Tri_IEH"               "Tri_FHA"               "Tri_DIM"
# [7924] "Tri_AWW"               "Tri_WWQ"               "Tri_WAW"
# [7927] "Tri_CKH"               "Tri_CIT"               "Tri_EWF"
# [7930] "Tri_WMV"               "Tri_KMY"               "Tri_YHD"
# [7933] "Tri_KHM"               "Tri_HYH"               "Tri_ANW"
# [7936] "Tri_VYW"               "Tri_AHE"               "Tri_HMN"
# [7939] "Tri_WKI"               "Tri_HQM"               "Tri_HAD"
# [7942] "Tri_FDH"               "Tri_HHK"               "Tri_VAM"
# [7945] "Tri_YTQ"               "Tri_SWC"               "Tri_YDW"
# [7948] "Tri_WCI"               "Tri_MHM"               "Tri_NWC"
# [7951] "Tri_PMG"               "Tri_YHH"               "Tri_MRY"
# [7954] "Tri_HQI"               "Tri_DYN"               "Tri_CSW"
# [7957] "Tri_IMM"               "Tri_IGM"               "Tri_NWS"
# [7960] "Tri_DWT"               "Tri_IAC"               "Tri_WRF"
# [7963] "Tri_KYF"               "Tri_PDW"               "Tri_YND"
# [7966] "Tri_NIM"               "Tri_MIN"               "Tri_GCF"
# [7969] "Tri_MIT"               "Tri_YIN"               "Tri_WQM"
# [7972] "Tri_MVW"               "Tri_NDH"               "Tri_QLM"
# [7975] "Tri_HYW"               "Tri_YMY"               "Tri_CHW"
# [7978] "Tri_NDC"               "Tri_HND"               "Tri_CIY"
# [7981] "Tri_YFK"               "Tri_THC"               "Tri_AYQ"
# [7984] "Tri_DAN"               "Tri_WDC"               "Tri_CCA"
# [7987] "Tri_QNN"               "Tri_CNQ"               "Tri_FQH"
# [7990] "Tri_CSM"               "Tri_ITY"               "Tri_QWN"
# [7993] "Tri_QYT"               "Tri_TYY"               "Tri_FWP"
# [7996] "Tri_WMC"               "Tri_WRW"               "Tri_NNA"
# [7999] "Tri_NWV"               "Tri_WKM"               "Tri_DYT"
# [8002] "Tri_MTY"               "Tri_YYA"               "Tri_RHY"
# [8005] "Tri_CCW"               "Tri_RMW"               "Tri_IMF"
# [8008] "Tri_HKW"               "Tri_MCC"               "Tri_GYN"
# [8011] "Tri_WRD"               "Tri_HDI"               "Tri_HWS"
# [8014] "Tri_WHT"               "Tri_RHW"               "Tri_HKI"
# [8017] "Tri_YPC"               "Tri_YNR"               "Tri_MHE"
# [8020] "Tri_NHM"               "Tri_PNH"               "Tri_HSC"
# [8023] "Tri_CYM"               "Tri_WMG"               "Tri_YYK"
# [8026] "Tri_TWG"               "Tri_RSN"               "Tri_WGN"
# [8029] "Tri_MMG"               "Tri_FDW"               "Tri_NCY"
# [8032] "Tri_YWM"               "Tri_HKS"               "Tri_WQN"
# [8035] "Tri_YQN"               "Tri_MHY"               "Tri_WTH"
# [8038] "Tri_WNI"               "Tri_WYM"               "Tri_VNY"
# [8041] "Tri_NMT"               "Tri_TGW"               "Tri_PMC"
# [8044] "Tri_MCE"               "Tri_YPK"               "Tri_CCH"
# [8047] "Tri_FCC"               "Tri_FCV"               "Tri_FWV"
# [8050] "Tri_FNQ"               "Tri_MYC"               "Tri_YCD"
# [8053] "Tri_IDC"               "Tri_FMY"               "Tri_WMR"
# [8056] "Tri_FWM"               "Tri_WCK"               "Tri_IEW"
# [8059] "Tri_WHK"               "Tri_MGW"               "Tri_MIK"
# [8062] "Tri_EWQ"               "Tri_DFH"               "Tri_CWS"
# [8065] "Tri_CTW"               "Tri_FWD"               "Tri_YWN"
# [8068] "Tri_NVH"               "Tri_QVM"               "Tri_NSM"
# [8071] "Tri_HHN"               "Tri_MWI"               "Tri_TWW"
# [8074] "Tri_QKW"               "Tri_NCW"               "Tri_CNN"
# [8077] "Tri_RCN"               "Tri_WGM"               "Tri_RWI"
# [8080] "Tri_DWN"               "Tri_YSY"               "Tri_WNA"
# [8083] "Tri_KWE"               "Tri_TYQ"               "Tri_WLY"
# [8086] "Tri_HPY"               "Tri_HFW"               "Tri_AWM"
# [8089] "Tri_QND"               "Tri_NDM"               "Tri_FRM"
# [8092] "Tri_PVW"               "Tri_HNQ"               "Tri_YTM"
# [8095] "Tri_WFI"               "Tri_MQV"               "Tri_IMH"
# [8098] "Tri_MHD"               "Tri_QIN"               "Tri_NCC"
# [8101] "Tri_IMV"               "Tri_WDM"               "Tri_DCM"
# [8104] "Tri_TMF"               "Tri_WET"               "Tri_HMI"
# [8107] "Tri_WSA"               "Tri_WYN"               "Tri_WVH"
# [8110] "Tri_CCC"               "Tri_MFG"               "Tri_WEY"
# [8113] "Tri_YHA"               "Tri_CKN"               "Tri_MYW"
# [8116] "Tri_CRH"               "Tri_HYF"               "Tri_WRC"
# [8119] "Tri_MEW"               "Tri_TYK"               "Tri_CYY"
# [8122] "Tri_WQI"               "Tri_RCY"               "Tri_NWN"
# [8125] "Tri_VYY"               "Tri_FHY"               "Tri_HYM"
# [8128] "Tri_NMC"               "Tri_VNW"               "Tri_SHY"
# [8131] "Tri_CWA"               "Tri_EFW"               "Tri_YMT"
# [8134] "Tri_MVF"               "Tri_YEH"               "Tri_TYF"
# [8137] "Tri_DMP"               "Tri_YRM"               "Tri_HTM"
# [8140] "Tri_ECC"               "Tri_WMF"               "Tri_GCM"
# [8143] "Tri_WTT"               "Tri_CEW"               "Tri_KCY"
# [8146] "Tri_PNM"               "Tri_VCC"               "Tri_VKW"
# [8149] "Tri_QWC"               "Tri_NAH"               "Tri_IHW"
# [8152] "Tri_CDD"               "Tri_YPF"               "Tri_DWM"
# [8155] "Tri_YYI"               "Tri_QHW"               "Tri_MKS"
# [8158] "Tri_PFR"               "Tri_YYY"               "Tri_IWI"
# [8161] "Tri_TYN"               "Tri_WDQ"               "Tri_KCG"
# [8164] "Tri_HNW"               "Tri_PKW"               "Tri_INW"
# [8167] "Tri_MMF"               "Tri_WCV"               "Tri_CWT"
# [8170] "Tri_NGW"               "Tri_ICY"               "Tri_WIH"
# [8173] "Tri_HCY"               "Tri_CYC"               "Tri_GFM"
# [8176] "Tri_WMW"               "Tri_HWF"               "Tri_IWC"
# [8179] "Tri_PKC"               "Tri_CDY"               "Tri_HIW"
# [8182] "Tri_WFE"               "Tri_WHP"               "Tri_KNH"
# [8185] "Tri_NDY"               "Tri_WWN"               "Tri_WHF"
# [8188] "Tri_LMW"               "Tri_NYK"               "Tri_WEM"
# [8191] "Tri_HQY"               "Tri_YWC"               "Tri_WMK"
# [8194] "Tri_NQQ"               "Tri_NQH"               "Tri_MRW"
# [8197] "Tri_HMM"               "Tri_SHA"               "Tri_RMF"
# [8200] "Tri_MCN"               "Tri_MFW"               "Tri_WWF"
# [8203] "Tri_YPM"               "Tri_QHC"               "Tri_CME"
# [8206] "Tri_WEF"               "Tri_KWW"               "Tri_WRH"
# [8209] "Tri_MKR"               "Tri_YQW"               "Tri_CCD"
# [8212] "Tri_YKQ"               "Tri_MYR"               "Tri_WFH"
# [8215] "Tri_PWH"               "Tri_PHM"               "Tri_MPI"
# [8218] "Tri_NMR"               "Tri_MRM"               "Tri_YTF"
# [8221] "Tri_YPW"               "Tri_YWL"               "Tri_HTW"
# [8224] "Tri_WVW"               "Tri_HCM"               "Tri_MDN"
# [8227] "Tri_WQF"               "Tri_KCM"               "Tri_YCM"
# [8230] "Tri_YYM"               "Tri_RWH"               "Tri_THM"
# [8233] "Tri_MWG"               "Tri_AMW"               "Tri_QWQ"
# [8236] "Tri_WHQ"               "Tri_HCW"               "Tri_CFH"
# [8239] "Tri_PWK"               "Tri_FIM"               "Tri_WFD"
# [8242] "Tri_VMM"               "Tri_EWY"               "Tri_YCY"
# [8245] "Tri_HWM"               "Tri_TYW"               "Tri_IYM"
# [8248] "Tri_EWM"               "Tri_CMV"               "Tri_CCE"
# [8251] "Tri_TCM"               "Tri_WHI"               "Tri_CHT"
# [8254] "Tri_FMF"               "Tri_CHN"               "Tri_YTR"
# [8257] "Tri_YHC"               "Tri_CAN"               "Tri_CYH"
# [8260] "Tri_EWC"               "Tri_PFH"               "Tri_WWH"
# [8263] "Tri_CCI"               "Tri_WVC"               "Tri_CRW"
# [8266] "Tri_QFW"               "Tri_MWD"               "Tri_FAW"
# [8269] "Tri_IMW"               "Tri_WHH"               "Tri_RWW"
# [8272] "Tri_WTM"               "Tri_CYA"               "Tri_MKC"
# [8275] "Tri_WYP"               "Tri_NWD"               "Tri_IWY"
# [8278] "Tri_TMN"               "Tri_DNM"               "Tri_GQW"
# [8281] "Tri_VWY"               "Tri_CHP"               "Tri_RCW"
# [8284] "Tri_CWG"               "Tri_MCH"               "Tri_FQM"
# [8287] "Tri_YCF"               "Tri_CMW"               "Tri_IWW"
# [8290] "Tri_WND"               "Tri_FMH"               "Tri_IMC"
# [8293] "Tri_MNC"               "Tri_YWF"               "Tri_FYW"
# [8296] "Tri_HKY"               "Tri_MMW"               "Tri_WNW"
# [8299] "Tri_YHW"               "Tri_NRM"               "Tri_MYH"
# [8302] "Tri_CHH"               "Tri_WCY"               "Tri_CTY"
# [8305] "Tri_MWC"               "Tri_GMW"               "Tri_WIW"
# [8308] "Tri_WGH"               "Tri_MCK"               "Tri_MDM"
# [8311] "Tri_NWH"               "Tri_VWM"               "Tri_WCM"
# [8314] "Tri_WQC"               "Tri_WCA"               "Tri_HWI"
# [8317] "Tri_WSN"               "Tri_WKP"               "Tri_MTC"
# [8320] "Tri_PCM"               "Tri_CYW"               "Tri_WGC"
# [8323] "Tri_WPY"               "Tri_DWG"               "Tri_MMQ"
# [8326] "Tri_AFH"               "Tri_WCQ"               "Tri_YTW"
# [8329] "Tri_DCW"               "Tri_PWQ"               "Tri_CYN"
# [8332] "Tri_WHV"               "Tri_DWW"               "Tri_CMD"
# [8335] "Tri_YWQ"               "Tri_WMP"               "Tri_NMY"
# [8338] "Tri_FMS"               "Tri_RHM"               "Tri_HWH"
# [8341] "Tri_HMK"               "Tri_MTW"               "Tri_YAM"
# [8344] "Tri_MWM"               "Tri_EDW"               "Tri_WNQ"
# [8347] "Tri_MNH"               "Tri_WTW"               "Tri_YYW"
# [8350] "Tri_MFH"               "Tri_DWH"               "Tri_YMM"
# [8353] "Tri_DIW"               "Tri_HDY"               "Tri_WIM"
# [8356] "Tri_HNC"               "Tri_CIM"               "Tri_WIQ"
# [8359] "Tri_CMC"               "Tri_YYH"               "Tri_TMY"
# [8362] "Tri_TYM"               "Tri_YGW"               "Tri_WNM"
# [8365] "Tri_MDC"               "Tri_MMN"               "Tri_CCM"
# [8368] "Tri_MCM"               "Tri_QCH"               "Tri_HMC"
# [8371] "Tri_FEW"               "Tri_YDC"               "Tri_CWP"
# [8374] "Tri_KWC"               "Tri_RWM"               "Tri_WWY"
# [8377] "Tri_CWC"               "Tri_WYH"               "Tri_DQW"
# [8380] "Tri_YNC"               "Tri_WWP"               "Tri_WCE"
# [8383] "Tri_FMC"               "Tri_YCW"               "Tri_WHW"
# [8386] "Tri_HDH"               "Tri_WQH"               "Tri_ECW"
# [8389] "Tri_CWY"               "Tri_HWW"               "Tri_CMP"
# [8392] "Tri_WHN"               "Tri_MWW"               "Tri_WFM"
# [8395] "Tri_NYW"               "Tri_WPM"               "Tri_DMW"
# [8398] "Tri_FCW"               "Tri_ICW"               "Tri_DNW"
# [8401] "Tri_SMW"               "Tri_YMC"               "Tri_WRY"
# [8404] "Tri_MCW"               "Tri_NHW"               "Tri_WQW"
# [8407] "Tri_WWD"               "Tri_DWY"               "Tri_NWW"
# [8410] "Tri_CWH"               "Tri_FWF"               "Tri_WYD"
# [8413] "Tri_HWT"               "Tri_MWF"               "Tri_WCW"
# [8416] "Tri_YWW"               "Tri_WMH"               "Tri_CMM"
# [8419] "Tri_WWM"               "Tri_WWR"               "Tri_WCN"
# [8422] "Tri_WWC"               "Tri_WDN"               "Tri_CWN"
# [8425] "Tri_WMY"               "isoelectric_point"     "gravy"
# [8428] "charge_pH7"

# %%
nrow(df)
df %>% filter(nchar(Seq)<=150) %>% nrow()
# df %>% filter(nchar(Seq)<=150) -> df
nrow(df)
# Out:
# [1] 15020
# [1] 11794
# [1] 15020

# %%
ggplot(df, aes(x = Supported_Enrichments, y = gravy, fill = Supported_Enrichments)) +
  # 小提琴图（分布）
  geom_violin(trim = FALSE, alpha = 0.5) +
  
  # 叠加盒形图（透明填充，仅中间显示）
  geom_boxplot(width = 0.15, fill = "white", outlier.shape = NA, color = "black") +

  # 美化主题与标签
  labs(
       x = "Enrichment method",
       y = "Hydrophobicity (GRAVY)") +
  theme_3() +
  theme(axis.text.x = element_text(angle = 45, hjust = 1),
        legend.position = "none") +
stat_compare_means(comparisons = combn(unique(df$Supported_Enrichments),2,simplify = FALSE),
                  method="wilcox.test",
                  label="p.signif")+
  scale_fill_manual(values = brewer.pal(length(unique(df$Supported_Enrichments)), "Set2")) ->p1

df -> df_1
df_1$Supported_Enrichments <- reorder(df_1$Supported_Enrichments, df_1$isoelectric_point, median)
ggplot(df_1, aes(x = Supported_Enrichments, y = isoelectric_point, fill = Supported_Enrichments)) +
  # 小提琴图（分布）
  geom_violin(trim = FALSE, alpha = 0.5) +
  
  # 叠加盒形图（透明填充，仅中间显示）
  geom_boxplot(width = 0.15, fill = "white", outlier.shape = NA, color = "black") +

  # 美化主题与标签
  labs(
       x = "Enrichment method",
       y = "Isoelectric point (pI)") +
  theme_3() +
  theme(axis.text.x = element_text(angle = 45, hjust = 1),
        legend.position = "none") +
stat_compare_means(comparisons = combn(unique(df$Supported_Enrichments),2,simplify = FALSE),
                  method="wilcox.test",
                  label="p.signif")+
  scale_fill_manual(values = brewer.pal(length(unique(df$Supported_Enrichments)), "Set2")) ->p2
p1
p2

ggsave(p1,filename = out_plot_1,height = 5,width = 5)
ggsave(p2,filename = out_plot_2,height = 5,width = 5)
# Out:
# plot without title
# plot without title

# %%
df[is.na(df$isoelectric_point),]
df[is.na(df$gravy),]
# Out:
# Warning message in cbind(parts$left, chars$ellip_h, parts$right, deparse.level = 0L):
# “number of rows of result is not a multiple of vector length (arg 2)”
# Warning message in cbind(parts$left, chars$ellip_h, parts$right, deparse.level = 0L):
# “number of rows of result is not a multiple of vector length (arg 2)”
# Warning message in cbind(parts$left, chars$ellip_h, parts$right, deparse.level = 0L):
# “number of rows of result is not a multiple of vector length (arg 2)”
# Warning message in cbind(parts$left, chars$ellip_h, parts$right, deparse.level = 0L):
# “number of rows of result is not a multiple of vector length (arg 2)”
#      Protein Seq Supported_Enrichments seq_length molecular_weight AA_A AA_C
#      AA_D AA_E AA_F ⋯ Tri_WWM Tri_WWR Tri_WCN Tri_WWC Tri_WDN Tri_CWN Tri_WMY
#      isoelectric_point gravy charge_pH7
# Warning message in cbind(parts$left, chars$ellip_h, parts$right, deparse.level = 0L):
# “number of rows of result is not a multiple of vector length (arg 2)”
# Warning message in cbind(parts$left, chars$ellip_h, parts$right, deparse.level = 0L):
# “number of rows of result is not a multiple of vector length (arg 2)”
# Warning message in cbind(parts$left, chars$ellip_h, parts$right, deparse.level = 0L):
# “number of rows of result is not a multiple of vector length (arg 2)”
# Warning message in cbind(parts$left, chars$ellip_h, parts$right, deparse.level = 0L):
# “number of rows of result is not a multiple of vector length (arg 2)”
#      Protein Seq Supported_Enrichments seq_length molecular_weight AA_A AA_C
#      AA_D AA_E AA_F ⋯ Tri_WWM Tri_WWR Tri_WCN Tri_WWC Tri_WDN Tri_CWN Tri_WMY
#      isoelectric_point gravy charge_pH7

# %%
df %>% na.omit() -> df_1
df_1 %>% dplyr::group_by(Supported_Enrichments) %>% dplyr::summarise(median_pI=median(isoelectric_point))
df_1 %>% group_by(Supported_Enrichments) %>% summarise(median_gravy=median(gravy))
# Out:
#   Supported_Enrichments median_pI
# 1 C8                    8.328139
# 2 MWCO                  8.753533
# 3 PAGE                  7.976045
# 4 PCP                   8.001768
#   Supported_Enrichments median_gravy
# 1 C8                    -0.2080302
# 2 MWCO                  -0.2591339
# 3 PAGE                  -0.1358491
# 4 PCP                   -0.2375000

# %%
ggplot(df, aes(x = Supported_Enrichments, y = gravy, fill = Supported_Enrichments)) +
  # 小提琴图（分布）
  geom_violin(trim = FALSE, alpha = 0.5) +
  
  # 叠加盒形图（透明填充，仅中间显示）
  geom_boxplot(width = 0.15, fill = "white", outlier.shape = NA, color = "black") +

  # 美化主题与标签
  labs(
       x = "Enrichment method",
       y = "Hydrophobicity (GRAVY)") +
  theme_3() +
  theme(axis.text.x = element_text(angle = 45, hjust = 1),
        legend.position = "none") +
stat_compare_means(comparisons = combn(unique(df$Supported_Enrichments),2,simplify = FALSE),
                  method="wilcox.test",
                  label="p.signif")+
  scale_fill_manual(values = brewer.pal(length(unique(df$Supported_Enrichments)), "Set2")) ->p1
ylim <- quantile(df$gravy, c(0.05, 0.95), na.rm = TRUE)
p1 + coord_cartesian(ylim = ylim)
# Out:
# plot without title

# %%
library(dplyr)
df_mean <- df %>%
  group_by(Supported_Enrichments) %>%
  summarise(mean = mean(gravy, na.rm=TRUE),
            se = sd(gravy, na.rm=TRUE)/sqrt(n()),
            .groups="drop")

ggplot(df_mean, aes(reorder(Supported_Enrichments, mean), mean)) +
  geom_pointrange(aes(ymin = mean - 1.96*se, ymax = mean + 1.96*se)) +
  coord_flip() + labs(x = "Enrichment method", y = "Hydrophobicity (GRAVY) (mean ±95%CI)") + theme_3() -> p1_supple
p1_supple
ggsave(p1_supple,filename = out_plot_1_1,height = 5,width = 5)
# Out:
# plot without title

# %%
library(dplyr)
library(ggpubr)
library(RColorBrewer)

# 1) 计算中位数顺序（从小到大）
ord <- df_1 %>%
  group_by(Supported_Enrichments) %>%
  summarise(med = median(isoelectric_point, na.rm = TRUE), .groups = "drop") %>%
  arrange(med) %>%
  pull(Supported_Enrichments)

# 2) 应用到因子水平（x 轴顺序 = 中位数从小到大）
df_1 <- df_1 %>%
  mutate(Supported_Enrichments = factor(Supported_Enrichments, levels = ord))

# 3) 颜色数量自适应（Set2 最多8色，超出则插值扩展）
n_grp <- length(ord)
pal   <- colorRampPalette(brewer.pal(min(8, max(3, n_grp)), "Set2"))(n_grp)

# 4) 重新绘图
p2 <- ggplot(df_1, aes(x = Supported_Enrichments, y = isoelectric_point, fill = Supported_Enrichments)) +
  geom_violin(trim = FALSE, alpha = 0.5) +
  geom_boxplot(width = 0.15, fill = "white", outlier.shape = NA, color = "black") +
  labs(x = "Enrichment method", y = "Isoelectric point (pI)") +
  theme_3() +
  theme(axis.text.x = element_text(angle = 45, hjust = 1),
        legend.position = "none") +
  stat_compare_means(
    comparisons = combn(levels(df_1$Supported_Enrichments), 2, simplify = FALSE),
    method = "wilcox.test",
    label = "p.signif"
  ) +
  scale_fill_manual(values = pal)
p2
ggsave(p2,filename = out_plot_2,height = 5,width = 5)
# Out:
# plot without title
