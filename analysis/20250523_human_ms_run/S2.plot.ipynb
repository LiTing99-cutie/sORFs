# %%
source("/rd1/user/lit/project/sORFs/sORFs.utils.R")
source("~/bin/lit_utils.R")
lib_text()
lib_plot()
# Out:
# Warning message:
# “程辑包‘stringr’是用R版本4.3.2 来建造的”

# %%
fread_c("/rd1/user/lit/project/sORFs/analysis/20250523_human_ms_run/stat_output/S2/sample_ms_stat_add_id_rate.txt") -> sample_ms_stat_add_id_rate

# %%
head(sample_ms_stat_add_id_rate)
# Out:
#   Sample             Protein_Group_N Peptdide_N PSM_N Eyzyme
# 1 21pcw_1_3_30K_LC_T 1404            24209      49969 Trypsin_LysC
# 2 21pcw_1_3_30K_LN_T 1459            21377      43989 Trypsin_LysN
# 3 21pcw_1_3_30K_T_AC 1267            19933      42288 Trypsin_ArgC
# 4 21pcw_1_3_30K_T_AN 1375            24678      48564 Trypsin_AspN
# 5 21pcw_1_3_30K_T_C  1598            21343      39714 Trypsin_Chymotrypsin
# 6 21pcw_1_3_30K_T_GC 1317            19242      36843 Trypsin_GluC
#   Period Enrichment Replicate ms2_count ID_rate
# 1 21pcw  MWCO       1         123342    0.4051256
# 2 21pcw  MWCO       1         117850    0.3732626
# 3 21pcw  MWCO       1         119284    0.3545153
# 4 21pcw  MWCO       1         122617    0.3960625
# 5 21pcw  MWCO       1         119262    0.3329979
# 6 21pcw  MWCO       1         125392    0.2938226

# %%
bar_plot_stated(sample_ms_stat_add_id_rate,x = "Sample",y = "ID_rate")
# Out:
# Warning message:
# “`aes_string()` was deprecated in ggplot2 3.0.0.
# ℹ Please use tidy evaluation idioms with `aes()`.
# ℹ See also `vignette("ggplot2-in-packages")` for more information.”
# plot without title

# %%
bar_plot_stated(sample_ms_stat_add_id_rate,x = "Sample",y = "Protein_Group_N")
# Out:
# plot without title

# %%
bar_plot_stated(sample_ms_stat_add_id_rate,x = "Sample",y = "Peptdide_N")
# Out:
# plot without title
