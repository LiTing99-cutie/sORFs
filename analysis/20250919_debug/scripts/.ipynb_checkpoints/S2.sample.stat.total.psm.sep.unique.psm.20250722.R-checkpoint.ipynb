# %%
source("/rd1/user/lit/project/sORFs/sORFs.utils.R")
source("~/bin/lit_utils.R")
lib_text()
lib_plot()

# %%
output_path <- "../results/S2"
create_path(output_path)

# %%
fread_c("../../20250721_human_ms_run/results/S1/sample_metadata_ordered.txt") -> sample_metadata
res_path <- "/rd1/user/lit/project/sORFs/analysis/20250827_1_all_new_db_new_para/processed/db_search_closed"
get_sample_ms_stat_from_path(res_path) -> sample_ms_stat
merge(sample_ms_stat,sample_metadata,by="Sample") %>% mutate(ID_rate=PSM_N/ms2_count) -> sample_ms_stat_add_id_rate
# 平均的谱图鉴定率为33.0%（比上次的20.9%要好）
mean(sample_ms_stat_add_id_rate$ID_rate)
fwrite_c(sample_ms_stat_add_id_rate,o("sample_ms_stat_add_id_rate.txt"))
# Out:
# [1] 0.3611042

# %%
# 初步查看有多少比对到小肽上的特异性肽段，以及多少被支持的小肽
get_total_psm(res_path) -> total_psm

# %%
colnames(total_psm)
# Out:
#  [1] "Spectrum"                    "Spectrum.File"
#  [3] "Peptide"                     "Modified.Peptide"
#  [5] "Extended.Peptide"            "Prev.AA"
#  [7] "Next.AA"                     "Peptide.Length"
#  [9] "Charge"                      "Retention"
# [11] "Observed.Mass"               "Calibrated.Observed.Mass"
# [13] "Observed.M.Z"                "Calibrated.Observed.M.Z"
# [15] "Calculated.Peptide.Mass"     "Calculated.M.Z"
# [17] "Delta.Mass"                  "SpectralSim"
# [19] "RTScore"                     "Expectation"
# [21] "Hyperscore"                  "Nextscore"
# [23] "Probability"                 "Number.of.Enzymatic.Termini"
# [25] "Number.of.Missed.Cleavages"  "Protein.Start"
# [27] "Protein.End"                 "Intensity"
# [29] "Assigned.Modifications"      "Observed.Modifications"
# [31] "Ion.Mobility"                "Purity"
# [33] "Is.Unique"                   "Protein"
# [35] "Protein.ID"                  "Entry.Name"
# [37] "Gene"                        "Protein.Description"
# [39] "Mapped.Genes"                "Mapped.Proteins"
# [41] "Sample"

# %%
total_psm %>% filter(grepl("^PB",Protein) & !grepl("canonical",Protein)) %>% filter(Is.Unique=="true") -> all_sample_sep_unique_psm_1
# 2141个unique谱图支持的蛋白质
length(unique(all_sample_sep_unique_psm_1$Protein))
# 2570个unique谱图支持的肽段
length(unique(all_sample_sep_unique_psm_1$Peptide))
fwrite_c(total_psm,path = o("total_psm.txt"))
fwrite_c(all_sample_sep_unique_psm_1,path = o("all_sample_sep_unique_psm.txt"))
# Out:
# [1] 17537
# [1] 18483
