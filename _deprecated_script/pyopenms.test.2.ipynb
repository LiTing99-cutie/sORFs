# %%
title="CAD20241224licq_BSEP_DDA_60min_E16_3_3-30K_LC-T_Slot2-18_1_4691.115881.115881.2"
mgf_path="/rd1/user/lit/project/sORFs/raw_data/MS/Guomics_SP_MSdata/CAD20241224licq_BSEP_DDA_60min/CAD20241224licq_BSEP_DDA_60min_E16_3_3-30K_LC-T_Slot2-18_1_4691_uncalibrated.mgf"
mzML_path="/rd1/user/lit/project/sORFs/raw_data/MS/Guomics_SP_MSdata/CAD20241224licq_BSEP_DDA_60min/CAD20241224licq_BSEP_DDA_60min_E16_3_3-30K_LC-T_Slot2-18_1_4691_calibrated.mzML"
# 肽段序列
pep_xml_path="/rd1/user/lit/project/sORFs/output/MS/Fragpipe_output/Formal/mouse/2025_02_06_default_ribo_database/Trypsin_LysC/CAD20241224licq_BSEP_DDA_60min_E16_3_3_30K_LC_T_Slot2_18_1_4691_d/interact-CAD20241224licq_BSEP_DDA_60min_E16_3_3-30K_LC-T_Slot2-18_1_4691.pep.xml"

# %%
from urllib.request import urlretrieve
import pyopenms as oms

gh = "https://raw.githubusercontent.com/OpenMS/pyopenms-docs/master"
urlretrieve(
    gh + "/src/data/YIC(Carbamidomethyl)DNQDTISSK.mzML", "observed.mzML"
)

exp = oms.MSExperiment()
# Load mzML file and obtain spectrum for peptide YIC(Carbamidomethyl)DNQDTISSK
oms.MzMLFile().load("observed.mzML", exp)

# Get first spectrum
spectra = exp.getSpectra()
observed_spectrum = spectra[0]
print(observed_spectrum)
# Out:
# <pyopenms._pyopenms_2.MSSpectrum object at 0x7feeac6c1230>

# %%
print("MS Level:", observed_spectrum.getMSLevel())  # 获取 MS 级别
print("Retention Time:", observed_spectrum.getRT())  # 获取保留时间（RT）
print("Number of Peaks:", observed_spectrum.size())  # 质谱峰的数量
# Out:
# MS Level: 2
# Retention Time: 1804.15795898438
# Number of Peaks: 158

# %%
# 获取mzML_path的第一个质谱
exp_test = oms.MSExperiment()
oms.MzMLFile().load(mzML_path, exp_test)
spectra_t = exp_test.getSpectra()
observed_spectrum_t = spectra_t[0]
print(observed_spectrum_t)
# Out:
# <pyopenms._pyopenms_2.MSSpectrum object at 0x7fedfad44090>

# %%
print("MS Level:", observed_spectrum_t.getMSLevel())  # 获取 MS 级别
print("Retention Time:", observed_spectrum_t.getRT())  # 获取保留时间（RT）
print("Number of Peaks:", observed_spectrum_t.size())  # 质谱峰的数量
# Out:
# MS Level: 2
# Retention Time: 13.399995267391205
# Number of Peaks: 136
