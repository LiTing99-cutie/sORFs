# %%
# 导入必要的库
import difflib

# 文件路径
file1_path = '/rd1/user/lit/project/sORFs/config/Test.workflow'
file2_path = '/rd1/user/lit/project/sORFs/output/MS/Fragpipe_output/2024_11_14_batch_run/Trypsin_LysC/config/fragpipe.workflow'

# 读取文件内容
with open(file1_path, 'r', encoding='utf-8') as file1, open(file2_path, 'r', encoding='utf-8') as file2:
    file1_lines = file1.readlines()
    file2_lines = file2.readlines()

# 使用difflib进行比较
diff = list(difflib.unified_diff(file1_lines, file2_lines, lineterm='', n=0))

# 格式化比较结果
diff  # 返回前几行差异内容以供预览（确保输出不会太长）

# 重新在windows端选择了一批参数，确实是类似的
# Out:
# ['--- ',
#  '+++ ',
#  '@@ -1 +1 @@',
#  '-# Workflow: Test\n',
#  '+# Workflow: workflow_LFQ_MBR_trypsin_lysc\n',
#  '@@ -6 +6 @@',
#  '-database.db-path=C\\:\\\\rd1\\\\user\\\\lit\\\\project\\\\sORFs\\\\custom_database\\\\2024-10-31-decoys-reviewed-isoforms-contam-UP000000589.fas\n',
#  '+database.db-path=/rd1/user/lit/project/sORFs/custom_database/2024-11-06-decoys-contam-uniprotkb_Mus_musculus_reviewed_canonical_isoform_2024_10_25.nonCano.sorf.filtered.fa.fas\n',
#  '@@ -138,2 +138,2 @@',
#  '-msfragger.misc.fragger.enzyme-dropdown-1=stricttrypsin\n',
#  '-msfragger.misc.fragger.enzyme-dropdown-2=null\n',
#  '+msfragger.misc.fragger.enzyme-dropdown-1=trypsin\n',
#  '+msfragger.misc.fragger.enzyme-dropdown-2=lysc\n',
#  '@@ -166,5 +166,5 @@',
#  '-msfragger.search_enzyme_cut_2=\n',
#  '-msfragger.search_enzyme_name_1=stricttrypsin\n',
#  '-msfragger.search_enzyme_name_2=null\n',
#  '-msfragger.search_enzyme_nocut_1=\n',
#  '-msfragger.search_enzyme_nocut_2=\n',
# ...

# %%
# 文件路径
file1_path = '/rd1/user/lit/project/sORFs/output/MS/Fragpipe_output/2024_11_06_2/fragpipe.workflow'
file2_path = '/rd1/user/lit/project/sORFs/output/MS/Fragpipe_output/2024_11_14_batch_run/Trypsin_LysC/config/fragpipe.workflow'

# 读取文件内容
with open(file1_path, 'r', encoding='utf-8') as file1, open(file2_path, 'r', encoding='utf-8') as file2:
    file1_lines = file1.readlines()
    file2_lines = file2.readlines()

# 使用difflib进行比较
diff = list(difflib.unified_diff(file1_lines, file2_lines, lineterm='', n=0))

# 格式化比较结果
diff  # 返回前几行差异内容以供预览（确保输出不会太长）

# 之前的那批和现在这批参数确实不仅仅是我想象中的只在一些参数上存在不同
# 文件行数相同才可以在shell中也进行比较
# Out:
# ['--- ',
#  '+++ ',
#  '@@ -1 +1 @@',
#  '-# FragPipe (22.0) runtime properties\n',
#  '+# Workflow: workflow_LFQ_MBR_trypsin_lysc\n',
#  '@@ -18 +18 @@',
#  '-diann.quantification-strategy-2=QuantUMS (high precision)\n',
#  '+diann.quantification-strategy-2=QuantUMS (high accuracy)\n',
#  '@@ -32 +32 @@',
#  '-diaumpire.AdjustFragIntensity=false\n',
#  '+diaumpire.AdjustFragIntensity=true\n',
#  '@@ -34,2 +34,2 @@',
#  '-diaumpire.CorrThreshold=\n',
#  '-diaumpire.DeltaApex=\n',
#  '+diaumpire.CorrThreshold=0\n',
#  '+diaumpire.DeltaApex=0.2\n',
#  '@@ -37,6 +37,6 @@',
#  '-diaumpire.Q1=false\n',
#  '-diaumpire.Q2=false\n',
#  '-diaumpire.Q3=false\n',
#  '-diaumpire.RFmax=\n',
#  '-diaumpire.RPmax=\n',
#  '-diaumpire.RTOverlap=\n',
#  '+diaumpire.Q1=true\n',
#  '+diaumpire.Q2=true\n',
#  '+diaumpire.Q3=true\n',
#  '+diaumpire.RFmax=500\n',
#  '+diaumpire.RPmax=25\n',
#  '+diaumpire.RTOverlap=0.3\n',
#  '@@ -44,8 +44,8 @@',
#  '-diaumpire.SE.IsoPattern=\n',
# ...

# %%
# 文件路径
file1_path = '/rd1/user/lit/project/sORFs/config/2024-11-01-1/fragpipe.workflow'
file2_path = '/rd1/user/lit/project/sORFs/output/MS/Fragpipe_output/2024_11_06_2/fragpipe.workflow'

# 读取文件内容
with open(file1_path, 'r', encoding='utf-8') as file1, open(file2_path, 'r', encoding='utf-8') as file2:
    file1_lines = file1.readlines()
    file2_lines = file2.readlines()

# 使用difflib进行比较
diff = list(difflib.unified_diff(file1_lines, file2_lines, lineterm='', n=0))

# 格式化比较结果
diff  # 返回前几行差异内容以供预览（确保输出不会太长）
# Out:
# ['--- ',
#  '+++ ',
#  '@@ -6 +6 @@',
#  '-database.db-path=/rd1/user/lit/project/sORFs/custom_database/2024-11-01-decoys-contam-uniprotkb_Mus_musculus_reviewed_canonical_isoform_2024_10_25.nonCano.sorf.NR.fa.fas\n',
#  '+database.db-path=/rd1/user/lit/project/sORFs/custom_database/2024-11-06-decoys-contam-uniprotkb_Mus_musculus_reviewed_canonical_isoform_2024_10_25.nonCano.sorf.filtered.fa.fas\n',
#  '@@ -59,3 +59,3 @@',
#  '-fragpipe-config.bin-diann=C\\:\\\\Users\\\\DELL\\\\Downloads\\\\FragPipe-jre-22.0\\\\fragpipe\\\\tools\\\\diann\\\\1.8.2_beta_8\\\\win\\\\DiaNN.exe\n',
#  '-fragpipe-config.bin-python=C\\:\\\\Users\\\\DELL\\\\anaconda3\\\\python\n',
#  '-fragpipe-config.tools-folder=C\\:\\\\Users\\\\DELL\\\\Downloads\\\\FragPipe-jre-22.0\\\\fragpipe\\\\lib\\\\..\\\\tools\n',
#  '+fragpipe-config.bin-diann=/rd1/user/lit/software/fragpipe/tools/diann/1.8.2_beta_8/linux/diann-1.8.1.8\n',
#  '+fragpipe-config.bin-python=/home/lit/rd1/anaconda3/envs/py3/bin/python\n',
# ...

# %%
# 文件路径
file1_path = '/rd1/user/lit/project/sORFs/output/MS/Fragpipe_output/F2_rerun_new_para/config/fragpipe.workflow'
file2_path = '/rd1/user/lit/project/sORFs/output/MS/Fragpipe_output/2024_11_14_batch_run/Trypsin_LysC/config/fragpipe.workflow'

# 读取文件内容
with open(file1_path, 'r', encoding='utf-8') as file1, open(file2_path, 'r', encoding='utf-8') as file2:
    file1_lines = file1.readlines()
    file2_lines = file2.readlines()

# 使用difflib进行比较
diff = list(difflib.unified_diff(file1_lines, file2_lines, lineterm='', n=0))

# 格式化比较结果
diff  # 返回前几行差异内容以供预览（确保输出不会太长）
# Out:
# []

# %%
# 文件路径
file1_path = '/rd1/user/lit/project/sORFs/output/MS/Fragpipe_output/2024_11_18_batch_run_6_samples_test_overlap/Trypsin_LysC/config/fragpipe.workflow'
file2_path = '/rd1/user/lit/project/sORFs/output/MS/Fragpipe_output/2024_11_14_batch_run/Trypsin_LysC/config/fragpipe.workflow'

# 读取文件内容
with open(file1_path, 'r', encoding='utf-8') as file1, open(file2_path, 'r', encoding='utf-8') as file2:
    file1_lines = file1.readlines()
    file2_lines = file2.readlines()

# 使用difflib进行比较
diff = list(difflib.unified_diff(file1_lines, file2_lines, lineterm='', n=0))

# 格式化比较结果
diff  # 返回前几行差异内容以供预览（确保输出不会太长）
# Out:
# []

# %%
# 文件路径
file1_path = '/rd1/user/lit/project/sORFs/config/2024-11-19/fragpipe.workflow'
file2_path = '/rd1/user/lit/project/sORFs/output/MS/Fragpipe_output/2024_11_14_batch_run/Trypsin_LysC/fragpipe.workflow'

# 读取文件内容
with open(file1_path, 'r', encoding='utf-8') as file1, open(file2_path, 'r', encoding='utf-8') as file2:
    file1_lines = file1.readlines()
    file2_lines = file2.readlines()

# 使用difflib进行比较
diff = list(difflib.unified_diff(file1_lines, file2_lines, lineterm='', n=0))

# 格式化比较结果
diff  # 返回前几行差异内容以供预览（确保输出不会太长）
# Out:
# ['--- ',
#  '+++ ',
#  '@@ -6 +6 @@',
#  '-database.db-path=/rd1/user/lit/project/sORFs/custom_database/2024-10-31-decoys-reviewed-isoforms-contam-UP000000589.fas\n',
#  '+database.db-path=/rd1/user/lit/project/sORFs/custom_database/2024-11-06-decoys-contam-uniprotkb_Mus_musculus_reviewed_canonical_isoform_2024_10_25.nonCano.sorf.filtered.fa.fas\n',
#  '@@ -18 +18 @@',
#  '-diann.quantification-strategy-2=QuantUMS (high precision)\n',
#  '+diann.quantification-strategy-2=QuantUMS (high accuracy)\n',
#  '@@ -32 +32 @@',
#  '-diaumpire.AdjustFragIntensity=false\n',
#  '+diaumpire.AdjustFragIntensity=true\n',
#  '@@ -34,2 +34,2 @@',
#  '-diaumpire.CorrThreshold=\n',
#  '-diaumpire.DeltaApex=\n',
#  '+diaumpire.CorrThreshold=0\n',
#  '+diaumpire.DeltaApex=0.2\n',
#  '@@ -37,6 +37,6 @@',
#  '-diaumpire.Q1=false\n',
#  '-diaumpire.Q2=false\n',
#  '-diaumpire.Q3=false\n',
#  '-diaumpire.RFmax=\n',
#  '-diaumpire.RPmax=\n',
#  '-diaumpire.RTOverlap=\n',
#  '+diaumpire.Q1=true\n',
# ...

# %%
# 文件路径
file1_path = '/rd1/user/lit/project/sORFs/config/2024-11-19/fragpipe.workflow'
file2_path = '/rd1/user/lit/project/sORFs/output/MS/Fragpipe_output/2024_11_06_2/fragpipe.workflow'

# 读取文件内容
with open(file1_path, 'r', encoding='utf-8') as file1, open(file2_path, 'r', encoding='utf-8') as file2:
    file1_lines = file1.readlines()
    file2_lines = file2.readlines()

# 使用difflib进行比较
diff = list(difflib.unified_diff(file1_lines, file2_lines, lineterm='', n=0))

# 格式化比较结果
diff  # 返回前几行差异内容以供预览（确保输出不会太长）
# Out:
# ['--- ',
#  '+++ ',
#  '@@ -6 +6 @@',
#  '-database.db-path=/rd1/user/lit/project/sORFs/custom_database/2024-10-31-decoys-reviewed-isoforms-contam-UP000000589.fas\n',
#  '+database.db-path=/rd1/user/lit/project/sORFs/custom_database/2024-11-06-decoys-contam-uniprotkb_Mus_musculus_reviewed_canonical_isoform_2024_10_25.nonCano.sorf.filtered.fa.fas\n',
#  '@@ -59,3 +59,3 @@',
#  '-fragpipe-config.bin-diann=C\\:\\\\Users\\\\DELL\\\\Downloads\\\\FragPipe-jre-22.0\\\\fragpipe\\\\tools\\\\diann\\\\1.8.2_beta_8\\\\win\\\\DiaNN.exe\n',
#  '-fragpipe-config.bin-python=C\\:\\\\Users\\\\DELL\\\\anaconda3\\\\python\n',
#  '-fragpipe-config.tools-folder=C\\:\\\\Users\\\\DELL\\\\Downloads\\\\FragPipe-jre-22.0\\\\fragpipe\\\\lib\\\\..\\\\tools\n',
#  '+fragpipe-config.bin-diann=/rd1/user/lit/software/fragpipe/tools/diann/1.8.2_beta_8/linux/diann-1.8.1.8\n',
#  '+fragpipe-config.bin-python=/home/lit/rd1/anaconda3/envs/py3/bin/python\n',
# ...

# %% [markdown]
# # 函数

# %%
import difflib

def compare_files(file1_path, file2_path):
    """
    比较两个文件内容的差异，使用unified diff格式输出。
    
    参数:
        file1_path (str): 第一个文件的路径
        file2_path (str): 第二个文件的路径
    
    返回:
        list: 包含差异的列表，每项为一行diff结果
    """
    try:
        # 读取文件内容
        with open(file1_path, 'r', encoding='utf-8') as file1, open(file2_path, 'r', encoding='utf-8') as file2:
            file1_lines = file1.readlines()
            file2_lines = file2.readlines()
        
        # 使用difflib进行比较
        diff = list(difflib.unified_diff(file1_lines, file2_lines, lineterm='', n=0))
        return diff
    
    except FileNotFoundError as e:
        print(f"文件未找到: {e}")
        return []
    except Exception as e:
        print(f"发生错误: {e}")
        return []

# %%
compare_files(
"/rd1/user/lit/project/sORFs/config/workflow_LFQ_MBR_trypsin_lysc_6_50_prot_1_no_MBR.workflow",
"/rd1/user/lit/project/sORFs/config/workflow_LFQ_MBR_trypsin_lysc.workflow"
)
# Out:
# ['--- ',
#  '+++ ',
#  '@@ -1 +1 @@',
#  '-# Workflow: workflow_LFQ_MBR_trypsin_lysc_6_50_prot_1_no_MBR\n',
#  '+# Workflow: workflow_LFQ_MBR_trypsin_lysc\n',
#  '@@ -6 +6 @@',
#  '-database.db-path=/rd1/user/lit/project/sORFs/custom_database/2024-11-06-decoys-contam-uniprotkb_Mus_musculus_reviewed_canonical_isoform_2024_10_25.nonCano.sorf.filtered.fa.fas\n',
#  '+database.db-path=\n',
#  '@@ -69 +69 @@',
#  '-ionquant.mbr=0\n',
#  '+ionquant.mbr=1\n']

# %%
compare_files(
"/rd1/user/lit/project/sORFs/output/MS/Fragpipe_output/trypsin_lysc_6_50_prot_1_no_MBR/fragpipe.workflow",
"/rd1/user/lit/project/sORFs/output/MS/Fragpipe_output/2024_11_14_batch_run/Trypsin_LysC/fragpipe.workflow"
)
# Out:
# ['--- ',
#  '+++ ',
#  '@@ -72 +72 @@',
#  '-ionquant.mbr=0\n',
#  '+ionquant.mbr=1\n',
#  '@@ -345 +345 @@',
#  '-workdir=/rd1/user/lit/project/sORFs/output/MS/Fragpipe_output/trypsin_lysc_6_50_prot_1_no_MBR\n',
#  '+workdir=/rd1/user/lit/project/sORFs/output/MS/Fragpipe_output/2024_11_14_batch_run/Trypsin_LysC/.\n']

# %%
compare_files(
"/rd1/user/lit/project/sORFs/config/workflow_LFQ_MBR_trypsin_lysc_6_50_prot_1_no_MBR.workflow",
"/rd1/user/lit/project/sORFs/config/workflow_LFQ_MBR_trypsin_lysc_6_50_prot_1_no_MBR_missed_cleavage_3.workflow"
)
# Out:
# ['--- ',
#  '+++ ',
#  '@@ -1 +1 @@',
#  '-# Workflow: workflow_LFQ_MBR_trypsin_lysc_6_50_prot_1_no_MBR\n',
#  '+# Workflow: workflow_LFQ_MBR_trypsin_lysc_6_50_prot_1_no_MBR_miss_cleavage_3\n',
#  '@@ -101,2 +101,2 @@',
#  '-msfragger.allowed_missed_cleavage_1=2\n',
#  '-msfragger.allowed_missed_cleavage_2=2\n',
#  '+msfragger.allowed_missed_cleavage_1=3\n',
#  '+msfragger.allowed_missed_cleavage_2=3\n']

# %%
compare_files(
"/rd1/user/lit/project/sORFs/config/workflow_LFQ_MBR_trypsin_lysc_6_50_prot_1_no_MBR.workflow",
"/rd1/user/lit/project/sORFs/config/workflow_LFQ_MBR_trypsin_lysc_6_50_prot_1_no_MBR_cysteine_variable.workflow"
)
# Out:
# ['--- ',
#  '+++ ',
#  '@@ -1 +1 @@',
#  '-# Workflow: workflow_LFQ_MBR_trypsin_lysc_6_50_prot_1_no_MBR\n',
#  '+# Workflow: workflow_LFQ_MBR_trypsin_lysc_6_50_prot_1_no_MBR_miss_cleavage_3\n',
#  '@@ -173,2 +173,2 @@',
#  '-msfragger.table.fix-mods=0.0,C-Term Peptide,true,-1; 0.0,N-Term Peptide,true,-1; 0.0,C-Term Protein,true,-1; 0.0,N-Term Protein,true,-1; 0.0,G (glycine),true,-1; 0.0,A (alanine),true,-1; 0.0,S (serine),true,-1; 0.0,P (proline),true,-1; 0.0,V (valine),true,-1; 0.0,T (threonine),true,-1; 57.02146,C (cysteine),true,-1; 0.0,L (leucine),true,-1; 0.0,I (isoleucine),true,-1; 0.0,N (asparagine),true,-1; 0.0,D (aspartic acid),true,-1; 0.0,Q (glutamine),true,-1; 0.0,K (lysine),true,-1; 0.0,E (glutamic acid),true,-1; 0.0,M (methionine),true,-1; 0.0,H (histidine),true,-1; 0.0,F (phenylalanine),true,-1; 0.0,R (arginine),true,-1; 0.0,Y (tyrosine),true,-1; 0.0,W (tryptophan),true,-1; 0.0,B ,true,-1; 0.0,J,true,-1; 0.0,O,true,-1; 0.0,U,true,-1; 0.0,X,true,-1; 0.0,Z,true,-1\n',
# ...

# %%
compare_files(
"/rd1/user/lit/project/sORFs/config/workflow_LFQ_MBR_null.workflow",
"/rd1/user/lit/project/sORFs/config/workflow_LFQ_MBR_6_50_prot_1_no_cleavage.workflow"
)
# Out:
# ['--- ',
#  '+++ ',
#  '@@ -1 +1 @@',
#  '-# Workflow: workflow_LFQ_MBR_null\n',
#  '+# Workflow: workflow_LFQ_MBR_trypsin_lysc_6_50_prot_1_no_MBR_no_cleavage\n',
#  '@@ -6 +6 @@',
#  '-database.db-path=\n',
#  '+database.db-path=C\\:\\\\rd1\\\\user\\\\lit\\\\project\\\\sORFs\\\\custom_database\\\\2024-10-31-decoys-reviewed-isoforms-contam-UP000000589.fas\n',
#  '@@ -101,2 +101,2 @@',
#  '-msfragger.allowed_missed_cleavage_1=2\n',
#  '-msfragger.allowed_missed_cleavage_2=2\n',
#  '+msfragger.allowed_missed_cleavage_1=0\n',
#  '+msfragger.allowed_missed_cleavage_2=0\n',
#  '@@ -138,2 +138,2 @@',
#  '-msfragger.misc.fragger.enzyme-dropdown-1=null\n',
#  '-msfragger.misc.fragger.enzyme-dropdown-2=null\n',
#  '+msfragger.misc.fragger.enzyme-dropdown-1=nocleavage\n',
#  '+msfragger.misc.fragger.enzyme-dropdown-2=nocleavage\n',
#  '@@ -165,6 +165,6 @@',
#  '-msfragger.search_enzyme_cut_1=\n',
#  '-msfragger.search_enzyme_cut_2=\n',
#  '-msfragger.search_enzyme_name_1=null\n',
# ...

# %%
compare_files(
"/rd1/user/lit/project/sORFs/config/workflow_LFQ_MBR_trypsin.workflow",
"/rd1/user/lit/project/sORFs/config/workflow_LFQ_MBR_6_50_prot_1_no_cleavage.workflow"
)
# Out:
# ['--- ',
#  '+++ ',
#  '@@ -1 +1 @@',
#  '-# Workflow: workflow_LFQ_MBR_trypsin\n',
#  '+# Workflow: workflow_LFQ_MBR_trypsin_lysc_6_50_prot_1_no_MBR_no_cleavage\n',
#  '@@ -6 +6 @@',
#  '-database.db-path=\n',
#  '+database.db-path=/rd1/user/lit/project/sORFs/custom_database/2024-11-06-decoys-contam-uniprotkb_Mus_musculus_reviewed_canonical_isoform_2024_10_25.nonCano.sorf.filtered.fa.fas\n',
#  '@@ -101,2 +101,2 @@',
#  '-msfragger.allowed_missed_cleavage_1=2\n',
#  '-msfragger.allowed_missed_cleavage_2=2\n',
#  '+msfragger.allowed_missed_cleavage_1=0\n',
#  '+msfragger.allowed_missed_cleavage_2=0\n',
#  '@@ -138,2 +138,2 @@',
#  '-msfragger.misc.fragger.enzyme-dropdown-1=trypsin\n',
#  '-msfragger.misc.fragger.enzyme-dropdown-2=null\n',
#  '+msfragger.misc.fragger.enzyme-dropdown-1=nocleavage\n',
#  '+msfragger.misc.fragger.enzyme-dropdown-2=nocleavage\n',
#  '@@ -165,6 +165,6 @@',
#  '-msfragger.search_enzyme_cut_1=KR\n',
#  '-msfragger.search_enzyme_cut_2=\n',
# ...

# %%
compare_files(
"/rd1/user/lit/project/sORFs/config/workflow_LFQ_MBR_trypsin_lysc.workflow",
"/rd1/user/lit/project/sORFs/output/MS/Fragpipe_output/Default_F2_prot_1/fragpipe.workflow"
)
# Out:
# ['--- ',
#  '+++ ',
#  '@@ -1 +1 @@',
#  '-# Workflow: workflow_LFQ_MBR_trypsin_lysc\n',
#  '+# FragPipe (22.0) runtime properties\n',
#  '@@ -6 +6 @@',
#  '-database.db-path=\n',
#  '+database.db-path=C\\:\\\\Users\\\\DELL\\\\Downloads\\\\FragPipe-output\\\\custom_database\\\\2024-11-06-decoys-contam-uniprotkb_Mus_musculus_reviewed_canonical_isoform_2024_10_25.nonCano.sorf.filtered.fa.fas\n',
#  '@@ -58,0 +59,3 @@',
#  '+fragpipe-config.bin-diann=C\\:\\\\Users\\\\DELL\\\\Downloads\\\\FragPipe-jre-22.0\\\\fragpipe\\\\tools\\\\diann\\\\1.8.2_beta_8\\\\win\\\\DiaNN.exe\n',
#  '+fragpipe-config.bin-python=C\\:\\\\Users\\\\DELL\\\\anaconda3\\\\python.exe\n',
#  '+fragpipe-config.tools-folder=C\\:\\\\Users\\\\DELL\\\\Downloads\\\\FragPipe-jre-22.0\\\\fragpipe\\\\tools\n',
#  '@@ -120 +123 @@',
#  '-msfragger.isotope_error=0/1/2\n',
#  '+msfragger.isotope_error=0/1/2/3\n',
#  '@@ -205,2 +208,2 @@',
#  '-phi-report.filter=--sequential --prot 1 --picked\n',
# ...

# %%
compare_files(
"/rd1/user/lit/project/sORFs/output/MS/Fragpipe_output/F2_rerun_new_para/fragpipe.workflow",
"/rd1/user/lit/project/sORFs/output/MS/Fragpipe_output/Default_F2_prot_1/fragpipe.workflow"
)
# Out:
# ['--- ',
#  '+++ ',
#  '@@ -6 +6 @@',
#  '-database.db-path=/rd1/user/lit/project/sORFs/custom_database/2024-11-06-decoys-contam-uniprotkb_Mus_musculus_reviewed_canonical_isoform_2024_10_25.nonCano.sorf.filtered.fa.fas\n',
#  '+database.db-path=C\\:\\\\Users\\\\DELL\\\\Downloads\\\\FragPipe-output\\\\custom_database\\\\2024-11-06-decoys-contam-uniprotkb_Mus_musculus_reviewed_canonical_isoform_2024_10_25.nonCano.sorf.filtered.fa.fas\n',
#  '@@ -59,3 +59,3 @@',
#  '-fragpipe-config.bin-diann=/rd1/user/lit/software/fragpipe/tools/diann/1.8.2_beta_8/linux/diann-1.8.1.8\n',
#  '-fragpipe-config.bin-python=/home/lit/rd1/anaconda3/envs/py3/bin/python\n',
#  '-fragpipe-config.tools-folder=/rd1/user/lit/project/sORFs/fragpipe_tools\n',
#  '+fragpipe-config.bin-diann=C\\:\\\\Users\\\\DELL\\\\Downloads\\\\FragPipe-jre-22.0\\\\fragpipe\\\\tools\\\\diann\\\\1.8.2_beta_8\\\\win\\\\DiaNN.exe\n',
#  '+fragpipe-config.bin-python=C\\:\\\\Users\\\\DELL\\\\anaconda3\\\\python.exe\n',
# ...

# %%
compare_files(
"/rd1/user/lit/project/sORFs/config/workflow_LFQ_MBR_trypsin_lysc_6_50_prot_1_no_MBR.workflow",
"/rd1/user/lit/project/sORFs/config/workflow_LFQ_MBR_trypsin_lysc_6_50_prot_1_no_MBR_no_ionquant.workflow"
)
# Out:
# ['--- ',
#  '+++ ',
#  '@@ -1 +1 @@',
#  '-# Workflow: workflow_LFQ_MBR_trypsin_lysc_6_50_prot_1_no_MBR\n',
#  '+# Workflow: workflow_LFQ_MBR_trypsin_lysc_6_50_prot_1_no_MBR_no_ionquant\n',
#  '@@ -69 +69 @@',
#  '-ionquant.mbr=0\n',
#  '+ionquant.mbr=1\n',
#  '@@ -271 +271 @@',
#  '-quantitation.run-label-free-quant=true\n',
#  '+quantitation.run-label-free-quant=false\n']

# %%
compare_files(
"/rd1/user/lit/project/sORFs/output/MS/Fragpipe_output/F2_rerun_new_para/fragpipe.workflow",
"/rd1/user/lit/project/sORFs/output/MS/Fragpipe_output/LFQ_MBR_trypsin_lysc_6_50_prot_1_no_MBR_no_ionquant/fragpipe.workflow"
)
# Out:
# ['--- ',
#  '+++ ',
#  '@@ -6 +6 @@',
#  '-database.db-path=/rd1/user/lit/project/sORFs/custom_database/2024-11-06-decoys-contam-uniprotkb_Mus_musculus_reviewed_canonical_isoform_2024_10_25.nonCano.sorf.filtered.fa.fas\n',
#  '+database.db-path=C\\:\\\\Users\\\\DELL\\\\Downloads\\\\FragPipe-output\\\\custom_database\\\\2024-11-06-decoys-contam-uniprotkb_Mus_musculus_reviewed_canonical_isoform_2024_10_25.nonCano.sorf.filtered.fa.fas\n',
#  '@@ -59,3 +59,3 @@',
#  '-fragpipe-config.bin-diann=/rd1/user/lit/software/fragpipe/tools/diann/1.8.2_beta_8/linux/diann-1.8.1.8\n',
#  '-fragpipe-config.bin-python=/home/lit/rd1/anaconda3/envs/py3/bin/python\n',
#  '-fragpipe-config.tools-folder=/rd1/user/lit/project/sORFs/fragpipe_tools\n',
#  '+fragpipe-config.bin-diann=C\\:\\\\Users\\\\DELL\\\\Downloads\\\\FragPipe-jre-22.0\\\\fragpipe\\\\tools\\\\diann\\\\1.8.2_beta_8\\\\win\\\\DiaNN.exe\n',
#  '+fragpipe-config.bin-python=C\\:\\\\Users\\\\DELL\\\\anaconda3\\\\python.exe\n',
# ...

# %%
compare_files(
"./output/MS/Fragpipe_output/2024_11_06_2/fragpipe.workflow",
"./output/MS/Fragpipe_output/LFQ_MBR_trypsin_lysc_6_50_prot_1_no_MBR_no_ionquant/fragpipe.workflow"
)
# Out:
# ['--- ',
#  '+++ ',
#  '@@ -6 +6 @@',
#  '-database.db-path=/rd1/user/lit/project/sORFs/custom_database/2024-11-06-decoys-contam-uniprotkb_Mus_musculus_reviewed_canonical_isoform_2024_10_25.nonCano.sorf.filtered.fa.fas\n',
#  '+database.db-path=C\\:\\\\Users\\\\DELL\\\\Downloads\\\\FragPipe-output\\\\custom_database\\\\2024-11-06-decoys-contam-uniprotkb_Mus_musculus_reviewed_canonical_isoform_2024_10_25.nonCano.sorf.filtered.fa.fas\n',
#  '@@ -18 +18 @@',
#  '-diann.quantification-strategy-2=QuantUMS (high precision)\n',
#  '+diann.quantification-strategy-2=QuantUMS (high accuracy)\n',
#  '@@ -32 +32 @@',
#  '-diaumpire.AdjustFragIntensity=false\n',
#  '+diaumpire.AdjustFragIntensity=true\n',
#  '@@ -34,2 +34,2 @@',
#  '-diaumpire.CorrThreshold=\n',
#  '-diaumpire.DeltaApex=\n',
#  '+diaumpire.CorrThreshold=0\n',
#  '+diaumpire.DeltaApex=0.2\n',
#  '@@ -37,6 +37,6 @@',
#  '-diaumpire.Q1=false\n',
#  '-diaumpire.Q2=false\n',
#  '-diaumpire.Q3=false\n',
#  '-diaumpire.RFmax=\n',
# ...

# %%
compare_files("/rd1/user/lit/project/sORFs/config/6_50_prot_1_non_specific_no_quant.workflow",
             "./output/MS/Fragpipe_output/LFQ_MBR_trypsin_lysc_6_50_prot_1_no_MBR_no_ionquant/fragpipe.workflow")
# Out:
# ['--- ',
#  '+++ ',
#  '@@ -1 +1 @@',
#  '-# Workflow: 6_50_prot_1_non_specific_no_quant\n',
#  '+# FragPipe (22.0) runtime properties\n',
#  '@@ -58,0 +59,3 @@',
#  '+fragpipe-config.bin-diann=C\\:\\\\Users\\\\DELL\\\\Downloads\\\\FragPipe-jre-22.0\\\\fragpipe\\\\tools\\\\diann\\\\1.8.2_beta_8\\\\win\\\\DiaNN.exe\n',
#  '+fragpipe-config.bin-python=C\\:\\\\Users\\\\DELL\\\\anaconda3\\\\python.exe\n',
#  '+fragpipe-config.tools-folder=C\\:\\\\Users\\\\DELL\\\\Downloads\\\\FragPipe-jre-22.0\\\\fragpipe\\\\tools\n',
#  '@@ -101,2 +104,2 @@',
#  '-msfragger.allowed_missed_cleavage_1=0\n',
#  '-msfragger.allowed_missed_cleavage_2=0\n',
#  '+msfragger.allowed_missed_cleavage_1=2\n',
#  '+msfragger.allowed_missed_cleavage_2=2\n',
#  '@@ -138,2 +141,2 @@',
#  '-msfragger.misc.fragger.enzyme-dropdown-1=nonspecific\n',
#  '-msfragger.misc.fragger.enzyme-dropdown-2=nonspecific\n',
#  '+msfragger.misc.fragger.enzyme-dropdown-1=trypsin\n',
#  '+msfragger.misc.fragger.enzyme-dropdown-2=lysc\n',
# ...

# %%
compare_files("/rd1/user/lit/project/sORFs/config/6_50_prot_1_non_specific_no_quant.workflow",
             "/rd1/user/lit/project/sORFs/config/6_50_prot_1_non_specific_no_cleavage_no_quant.workflow")
# Out:
# ['--- ',
#  '+++ ',
#  '@@ -1 +1 @@',
#  '-# Workflow: 6_50_prot_1_non_specific_no_quant\n',
#  '+# Workflow: 6_50_prot_1_non_specific_no_cleavage_no_quant\n',
#  '@@ -138,2 +138,2 @@',
#  '-msfragger.misc.fragger.enzyme-dropdown-1=nonspecific\n',
#  '-msfragger.misc.fragger.enzyme-dropdown-2=nonspecific\n',
#  '+msfragger.misc.fragger.enzyme-dropdown-1=nocleavage\n',
#  '+msfragger.misc.fragger.enzyme-dropdown-2=nocleavage\n',
#  '@@ -167,4 +167,4 @@',
#  '-msfragger.search_enzyme_name_1=nonspecific\n',
#  '-msfragger.search_enzyme_name_2=nonspecific\n',
#  '-msfragger.search_enzyme_nocut_1=\n',
#  '-msfragger.search_enzyme_nocut_2=\n',
#  '+msfragger.search_enzyme_name_1=nocleavage\n',
#  '+msfragger.search_enzyme_name_2=nocleavage\n',
#  '+msfragger.search_enzyme_nocut_1=-\n',
#  '+msfragger.search_enzyme_nocut_2=-\n']

# %%
compare_files("/rd1/user/lit/project/sORFs/config/workflow_LFQ_MBR_6_50_prot_1_no_cleavage.workflow",
             "/rd1/user/lit/project/sORFs/config/6_50_prot_1_non_specific_no_cleavage_no_quant.workflow")
# Out:
# ['--- ',
#  '+++ ',
#  '@@ -1 +1 @@',
#  '-# Workflow: workflow_LFQ_MBR_trypsin_lysc_6_50_prot_1_no_MBR_no_cleavage\n',
#  '+# Workflow: 6_50_prot_1_non_specific_no_cleavage_no_quant\n',
#  '@@ -6 +6 @@',
#  '-database.db-path=/rd1/user/lit/project/sORFs/custom_database/2024-11-06-decoys-contam-uniprotkb_Mus_musculus_reviewed_canonical_isoform_2024_10_25.nonCano.sorf.filtered.fa.fas\n',
#  '+database.db-path=C\\:\\\\Users\\\\DELL\\\\Downloads\\\\FragPipe-output\\\\custom_database\\\\2024-11-06-decoys-contam-uniprotkb_Mus_musculus_reviewed_canonical_isoform_2024_10_25.nonCano.sorf.filtered.fa.fas\n',
#  '@@ -145 +145 @@',
#  '-msfragger.num_enzyme_termini=2\n',
#  '+msfragger.num_enzyme_termini=0\n',
#  '@@ -271 +271 @@',
#  '-quantitation.run-label-free-quant=true\n',
#  '+quantitation.run-label-free-quant=false\n',
#  '@@ -342 +342 @@',
# ...

# %%
compare_files("/rd1/user/lit/project/sORFs/config/workflow_LFQ_MBR_null.workflow",
             "/rd1/user/lit/project/sORFs/config/6_50_prot_1_non_specific_no_quant.workflow")
# Out:
# ['--- ',
#  '+++ ',
#  '@@ -1 +1 @@',
#  '-# Workflow: workflow_LFQ_MBR_null\n',
#  '+# Workflow: 6_50_prot_1_non_specific_no_quant\n',
#  '@@ -6 +6 @@',
#  '-database.db-path=\n',
#  '+database.db-path=/rd1/user/lit/project/sORFs/custom_database/2024-11-06-decoys-contam-uniprotkb_Mus_musculus_reviewed_canonical_isoform_2024_10_25.nonCano.sorf.filtered.fa.fas\n',
#  '@@ -101,2 +101,2 @@',
#  '-msfragger.allowed_missed_cleavage_1=2\n',
#  '-msfragger.allowed_missed_cleavage_2=2\n',
#  '+msfragger.allowed_missed_cleavage_1=0\n',
#  '+msfragger.allowed_missed_cleavage_2=0\n',
#  '@@ -138,2 +138,2 @@',
#  '-msfragger.misc.fragger.enzyme-dropdown-1=null\n',
#  '-msfragger.misc.fragger.enzyme-dropdown-2=null\n',
#  '+msfragger.misc.fragger.enzyme-dropdown-1=nonspecific\n',
#  '+msfragger.misc.fragger.enzyme-dropdown-2=nonspecific\n',
#  '@@ -145 +145 @@',
#  '-msfragger.num_enzyme_termini=2\n',
#  '+msfragger.num_enzyme_termini=0\n',
#  '@@ -165,4 +165,4 @@',
# ...

# %%
compare_files("/rd1/user/lit/project/sORFs/config/6_50_prot_1_non_specific_no_quant.workflow",
             "/rd1/user/lit/project/sORFs/output/MS/Fragpipe_output/F1_6_50_prot_1_non_specific_no_quant_uniprot_step_1/fragpipe.workflow")
# Out:
# ['--- ',
#  '+++ ',
#  '@@ -1 +1 @@',
#  '-# Workflow: 6_50_prot_1_non_specific_no_quant\n',
#  '+# FragPipe (22.0) runtime properties\n',
#  '@@ -6 +6 @@',
#  '-database.db-path=/rd1/user/lit/project/sORFs/custom_database/2024-11-06-decoys-contam-uniprotkb_Mus_musculus_reviewed_canonical_isoform_2024_10_25.nonCano.sorf.filtered.fa.fas\n',
#  '+database.db-path=D\\:\\\\FragPipe-output\\\\custom_database\\\\2024-11-21-decoys-contam-uniprotkb_Mus_musculus_reviewed_canonical_isoform_2024_10_25.fasta.fas\n',
#  '@@ -58,0 +59,3 @@',
#  '+fragpipe-config.bin-diann=C\\:\\\\Users\\\\DELL\\\\Downloads\\\\FragPipe-jre-22.0\\\\fragpipe\\\\tools\\\\diann\\\\1.8.2_beta_8\\\\win\\\\DiaNN.exe\n',
#  '+fragpipe-config.bin-python=C\\:\\\\Users\\\\DELL\\\\anaconda3\\\\python.exe\n',
#  '+fragpipe-config.tools-folder=C\\:\\\\Users\\\\DELL\\\\Downloads\\\\FragPipe-jre-22.0\\\\fragpipe\\\\tools\n',
#  '@@ -207 +210 @@',
#  '-phi-report.print-decoys=false\n',
#  '+phi-report.print-decoys=true\n',
# ...

# %%
compare_files("/rd1/user/lit/project/sORFs/output/MS/Fragpipe_output/Default_F2_prot_1/fragpipe.workflow",
             "/rd1/user/lit/project/sORFs/config/workflow_LFQ_MBR_trypsin_chymotrypsin.workflow")
# Out:
# ['--- ',
#  '+++ ',
#  '@@ -1 +1 @@',
#  '-# FragPipe (22.0) runtime properties\n',
#  '+# Workflow: workflow_LFQ_MBR_trypsin_chymotrypsin\n',
#  '@@ -6 +6 @@',
#  '-database.db-path=C\\:\\\\Users\\\\DELL\\\\Downloads\\\\FragPipe-output\\\\custom_database\\\\2024-11-06-decoys-contam-uniprotkb_Mus_musculus_reviewed_canonical_isoform_2024_10_25.nonCano.sorf.filtered.fa.fas\n',
#  '+database.db-path=\n',
#  '@@ -59,3 +58,0 @@',
#  '-fragpipe-config.bin-diann=C\\:\\\\Users\\\\DELL\\\\Downloads\\\\FragPipe-jre-22.0\\\\fragpipe\\\\tools\\\\diann\\\\1.8.2_beta_8\\\\win\\\\DiaNN.exe\n',
#  '-fragpipe-config.bin-python=C\\:\\\\Users\\\\DELL\\\\anaconda3\\\\python.exe\n',
#  '-fragpipe-config.tools-folder=C\\:\\\\Users\\\\DELL\\\\Downloads\\\\FragPipe-jre-22.0\\\\fragpipe\\\\tools\n',
#  '@@ -123 +120 @@',
#  '-msfragger.isotope_error=0/1/2/3\n',
#  '+msfragger.isotope_error=0/1/2\n',
#  '@@ -142 +139 @@',
#  '-msfragger.misc.fragger.enzyme-dropdown-2=lysc\n',
# ...

# %%
compare_files("/rd1/user/lit/project/sORFs/output/MS/Fragpipe_output/Default_F2_prot_1/fragpipe.workflow",
             "/rd1/user/lit/project/sORFs/config/Default/Trypsin_lysc_6_50_prot_1.workflow")
# Out:
# ['--- ',
#  '+++ ',
#  '@@ -1 +1 @@',
#  '-# FragPipe (22.0) runtime properties\n',
#  '+# Workflow: Trypsin_lysc_6_50_prot_1\n',
#  '@@ -59,3 +58,0 @@',
#  '-fragpipe-config.bin-diann=C\\:\\\\Users\\\\DELL\\\\Downloads\\\\FragPipe-jre-22.0\\\\fragpipe\\\\tools\\\\diann\\\\1.8.2_beta_8\\\\win\\\\DiaNN.exe\n',
#  '-fragpipe-config.bin-python=C\\:\\\\Users\\\\DELL\\\\anaconda3\\\\python.exe\n',
#  '-fragpipe-config.tools-folder=C\\:\\\\Users\\\\DELL\\\\Downloads\\\\FragPipe-jre-22.0\\\\fragpipe\\\\tools\n',
#  '@@ -345 +342 @@',
#  '-workdir=C\\:\\\\Users\\\\DELL\\\\Downloads\\\\FragPipe-output\\\\Default_F2_prot_1\n',
#  '+workflow.description=Description not present\n',
#  '@@ -349,2 +346 @@',
#  '-workflow.ram=0\n',
#  '-workflow.threads=30\n',
#  '+workflow.saved-with-ver=22.0\n']

# %%
compare_files("/rd1/user/lit/project/sORFs/config/Default/Trypsin_chymotrypsin_6_50_prot_1.workflow",
             "/rd1/user/lit/project/sORFs/test.txt")
# Out:
# ['--- ',
#  '+++ ',
#  '@@ -1 +1 @@',
#  '-# Workflow: Trypsin_chymotrypsin_6_50_prot_1\n',
#  '+# Workflow: Trypsin_lysc_6_50_prot_1\n']

# %%
compare_files(
"/rd1/user/lit/project/sORFs/config/Default/Trypsin_lysc_6_50_prot_1.workflow",
"/rd1/user/lit/project/sORFs/output/MS/Fragpipe_output/Default_F2_prot_1/fragpipe.workflow"
)
# Out:
# ['--- ',
#  '+++ ',
#  '@@ -1 +1 @@',
#  '-# Workflow: Trypsin_lysc_6_50_prot_1\n',
#  '+# FragPipe (22.0) runtime properties\n',
#  '@@ -58,0 +59,3 @@',
#  '+fragpipe-config.bin-diann=C\\:\\\\Users\\\\DELL\\\\Downloads\\\\FragPipe-jre-22.0\\\\fragpipe\\\\tools\\\\diann\\\\1.8.2_beta_8\\\\win\\\\DiaNN.exe\n',
#  '+fragpipe-config.bin-python=C\\:\\\\Users\\\\DELL\\\\anaconda3\\\\python.exe\n',
#  '+fragpipe-config.tools-folder=C\\:\\\\Users\\\\DELL\\\\Downloads\\\\FragPipe-jre-22.0\\\\fragpipe\\\\tools\n',
#  '@@ -342 +345 @@',
#  '-workflow.description=Description not present\n',
#  '+workdir=C\\:\\\\Users\\\\DELL\\\\Downloads\\\\FragPipe-output\\\\Default_F2_prot_1\n',
#  '@@ -346 +349,2 @@',
#  '-workflow.saved-with-ver=22.0\n',
#  '+workflow.ram=0\n',
#  '+workflow.threads=30\n']

# %%
compare_files(
"/rd1/user/lit/project/sORFs/config/Default/Trypsin_lysc_6_50_prot_1.workflow",
"/rd1/user/lit/project/sORFs/output/MS/Fragpipe_output/Default_F2_prot_1/fragpipe.workflow"
)

# %%
compare_files(
"/rd1/user/lit/project/sORFs/config/Default/Trypsin_lysc_6_50_prot_1.workflow",
"/rd1/user/lit/project/sORFs/config/Open/6_50_prot_1.workflow"
)
# Out:
# ['--- ',
#  '+++ ',
#  '@@ -1 +1 @@',
#  '-# Workflow: Trypsin_lysc_6_50_prot_1\n',
#  '+# Workflow: 6_50_prot_1\n',
#  '@@ -8 +8 @@',
#  '-crystalc.run-crystalc=false\n',
#  '+crystalc.run-crystalc=true\n',
#  '@@ -61 +61 @@',
#  '-freequant.run-freequant=false\n',
#  '+freequant.run-freequant=true\n',
#  '@@ -69 +69 @@',
#  '-ionquant.mbr=1\n',
#  '+ionquant.mbr=0\n',
#  '@@ -85 +85 @@',
#  '-ionquant.run-ionquant=true\n',
#  '+ionquant.run-ionquant=false\n',
#  '@@ -97 +97 @@',
#  '-msbooster.run-msbooster=true\n',
#  '+msbooster.run-msbooster=false\n',
#  '@@ -120 +120 @@',
#  '-msfragger.isotope_error=0/1/2/3\n',
#  '+msfragger.isotope_error=0\n',
#  '@@ -122 +122 @@',
#  '-msfragger.localize_delta_mass=false\n',
#  '+msfragger.localize_delta_mass=true\n',
#  '@@ -138,2 +138,2 @@',
#  '-msfragger.misc.fragger.enzyme-dropdown-1=trypsin\n',
#  '-msfragger.misc.fragger.enzyme-dropdown-2=lysc\n',
#  '+msfragger.misc.fragger.enzyme-dropdown-1=stricttrypsin\n',
# ...

# %%
compare_files(
"/rd1/user/lit/project/sORFs/output/MS/Fragpipe_output/F2_rerun_new_para/config/fragpipe.workflow",
"/rd1/user/lit/project/sORFs/output/MS/Fragpipe_output/2024_12_03_batch_run/Trypsin_LysC/config/fragpipe.workflow"
)
# Out:
# ['--- ',
#  '+++ ',
#  '@@ -1 +1 @@',
#  '-# Workflow: workflow_LFQ_MBR_trypsin_lysc\n',
#  '+# Workflow: Trypsin_lysc_6_50_prot_1\n',
#  '@@ -120 +120 @@',
#  '-msfragger.isotope_error=0/1/2\n',
#  '+msfragger.isotope_error=0/1/2/3\n',
#  '@@ -205,2 +205,2 @@',
#  '-phi-report.filter=--sequential --prot 1 --picked\n',
#  '-phi-report.pep-level-summary=false\n',
#  '+phi-report.filter=--sequential --picked --prot 1\n',
#  '+phi-report.pep-level-summary=true\n',
#  '@@ -208 +208 @@',
#  '-phi-report.prot-level-summary=false\n',
#  '+phi-report.prot-level-summary=true\n',
#  '@@ -242 +242 @@',
#  '-ptmshepherd.iontype_c=false\n',
#  '+ptmshepherd.iontype_c=true\n',
#  '@@ -245 +245 @@',
#  '-ptmshepherd.iontype_z=false\n',
#  '+ptmshepherd.iontype_z=true\n',
#  '@@ -271 +271 @@',
#  '-quantitation.run-label-free-quant=true\n',
#  '+quantitation.run-label-free-quant=false\n',
#  '@@ -301 +301 @@',
#  '-speclibgen.easypqp.rt-cal=noiRT\n',
#  '+speclibgen.easypqp.rt-cal=ciRT\n',
# ...
