# %%
import pandas as pd
pd.set_option('display.width', 1000)  # 设置最大行宽度
pd.set_option('display.max_columns', None)  # 显示所有列

# %%
collapsed_filtered=pd.read_csv("../processed/classify/collapsed_classification.filtered_lite_classification.txt",sep='\t')

# %%
collapsed_filtered.columns
# Out:
# Index(['isoform', 'chrom', 'strand', 'length', 'exons', 'structural_category',
#        'associated_gene', 'associated_transcript', 'ref_length', 'ref_exons',
#        'diff_to_TSS', 'diff_to_TTS', 'diff_to_gene_TSS', 'diff_to_gene_TTS',
#        'subcategory', 'RTS_stage', 'all_canonical', 'min_sample_cov',
#        'min_cov', 'min_cov_pos', 'sd_cov', 'FL.BioSample_6',
#        'FL_TPM.BioSample_6', 'FL_TPM.BioSample_6_log10', 'n_indels',
#        'n_indels_junc', 'bite', 'iso_exp', 'gene_exp', 'ratio_exp',
#        'FSM_class', 'coding', 'ORF_length', 'CDS_length', 'CDS_start',
#        'CDS_end', 'CDS_genomic_start', 'CDS_genomic_end', 'predicted_NMD',
#        'perc_A_downstream_TTS', 'seq_A_downstream_TTS', 'dist_to_CAGE_peak',
#        'within_CAGE_peak', 'dist_to_polyA_site', 'within_polyA_site',
#        'polyA_motif', 'polyA_dist', 'polyA_motif_found', 'ORF_seq',
#        'ratio_TSS', 'fl_assoc', 'cell_barcodes'],
#       dtype='object')

# %%
collapsed_filtered.head()
# FL开头的列是计数，例如FL.BioSample_6, FL.BioSample_6以及FL_TPM.BioSample_6_log10
# Out:
#   isoform chrom strand  length  exons   structural_category associated_gene associated_transcript  ref_length  ref_exons  diff_to_TSS  diff_to_TTS  diff_to_gene_TSS  diff_to_gene_TTS                    subcategory RTS_stage all_canonical  min_sample_cov  min_cov  min_cov_pos  sd_cov  FL.BioSample_6  FL_TPM.BioSample_6  FL_TPM.BioSample_6_log10  n_indels  n_indels_junc   bite  iso_exp  gene_exp  ratio_exp FSM_class      coding  ORF_length  CDS_length  CDS_start  CDS_end  CDS_genomic_start  CDS_genomic_end  predicted_NMD  perc_A_downstream_TTS  seq_A_downstream_TTS  dist_to_CAGE_peak  within_CAGE_peak  dist_to_polyA_site  within_polyA_site  polyA_motif  polyA_dist  polyA_motif_found  ORF_seq  ratio_TSS  fl_assoc  cell_barcodes isoform_base    gene
# 0  PB.1.2  chr1      -    3057      4  novel_not_in_catalog          WASH7P                 novel      1351.0       11.0          NaN          NaN             211.0               2.0               intron_retention     FALSE     canonical             NaN      NaN          NaN     NaN               2            0.317421                 -0.498364       NaN            NaN  False      NaN       NaN        NaN         B  non_coding         NaN         NaN        NaN      NaN                NaN              NaN            NaN                   40.0  AACAGTGTGCTTTTAATAAA                NaN               NaN                 NaN                NaN          NaN         NaN                NaN      NaN        NaN         2            NaN         PB.1  WASH7P
# 1  PB.1.4  chr1      -    2744      7  novel_not_in_catalog          WASH7P                 novel      1351.0       11.0          NaN          NaN             220.0               2.0               intron_retention     FALSE     canonical             NaN      NaN          NaN     NaN               5            0.793552                 -0.100424       NaN            NaN  False      NaN       NaN        NaN         B  non_coding         NaN         NaN        NaN      NaN                NaN              NaN            NaN                   40.0  AACAGTGTGCTTTTAATAAA                NaN               NaN                 NaN                NaN          NaN         NaN                NaN      NaN        NaN         5            NaN         PB.1  WASH7P
# 2  PB.1.5  chr1      -    2301      9  novel_not_in_catalog          WASH7P                 novel      1351.0       11.0          NaN          NaN           10897.0               2.0               intron_retention     FALSE     canonical             NaN      NaN          NaN     NaN               2            0.317421                 -0.498364       NaN            NaN   True      NaN       NaN        NaN         B  non_coding         NaN         NaN        NaN      NaN                NaN              NaN            NaN                   40.0  AACAGTGTGCTTTTAATAAA                NaN               NaN                 NaN                NaN          NaN         NaN                NaN      NaN        NaN         2            NaN         PB.1  WASH7P
# 3  PB.1.6  chr1      -    1924      9  novel_not_in_catalog          WASH7P                 novel      1351.0       11.0          NaN          NaN             223.0               2.0               intron_retention     FALSE     canonical             NaN      NaN          NaN     NaN               2            0.317421                 -0.498364       NaN            NaN   True      NaN       NaN        NaN         B  non_coding         NaN         NaN        NaN      NaN                NaN              NaN            NaN                   40.0  AACAGTGTGCTTTTAATAAA                NaN               NaN                 NaN                NaN          NaN         NaN                NaN      NaN        NaN         2            NaN         PB.1  WASH7P
# 4  PB.1.7  chr1      -    3644     11  novel_not_in_catalog          WASH7P                 novel      1351.0       11.0          NaN          NaN            2383.0              -3.0  at_least_one_novel_splicesite     FALSE     canonical             NaN      NaN          NaN     NaN               2            0.317421                 -0.498364       NaN            NaN   True      NaN       NaN        NaN         B  non_coding         NaN         NaN        NaN      NaN                NaN              NaN            NaN                   35.0  AAACCAACAGTGTGCTTTTA                NaN               NaN                 NaN                NaN          NaN         NaN                NaN      NaN        NaN         2            NaN         PB.1  WASH7P

# %%
collapsed_filtered["FL.BioSample_6"].sum()
# Out:
# np.int64(6300782)

# %%
collapsed_filtered['associated_gene'].nunique()
# collapsed_filtered['associated_transcript'].nunique()
# Out:
# 18455

# %%
collapsed_filtered.structural_category.value_counts()
# Out:
# structural_category
# incomplete-splice_match    120376
# full-splice_match           93341
# novel_in_catalog            46505
# novel_not_in_catalog        27861
# fusion                       1168
# intergenic                    674
# genic                         484
# antisense                     283
# moreJunctions                  49
# Name: count, dtype: int64

# %%
collapsed_filtered.subcategory.value_counts()
# Out:
# subcategory
# 3prime_fragment                     95437
# intron_retention                    27555
# at_least_one_novel_splicesite       23531
# alternative_3end                    22766
# alternative_3end5end                21239
# alternative_5end                    18725
# combination_of_known_junctions      18449
# mono-exon                           16332
# reference_match                     14279
# 5prime_fragment                     12242
# combination_of_known_splicesites    10034
# internal_fragment                    7819
# multi-exon                           2300
# no_subcategory                         33
# Name: count, dtype: int64

# %% [markdown]
# # 查看isoform去掉后缀之后的gene id和实际上的gene id之间的对应关系

# %%
df=collapsed_filtered
# 去掉第一列的数字后缀
df['isoform_base'] = df.iloc[:, 0].str.replace(r'\.\d+$', '', regex=True)
df['gene'] = df.iloc[:, 6]  # 第7列

# 找一对多关系
isoform_to_gene = df.groupby('isoform_base')['gene'].agg(set)
one_to_many = isoform_to_gene[isoform_to_gene.apply(len) > 1]

print("One-to-many relationships:")
for i, (isoform, genes) in enumerate(one_to_many.items()):
    if i >= 5:  # 只显示前5个
        break
    print(f"{isoform} -> {list(genes)}")

# 找多对一关系
gene_to_isoform = df.groupby('gene')['isoform_base'].agg(set)
many_to_one = gene_to_isoform[gene_to_isoform.apply(len) > 1]

print("\nMany-to-one relationships:")
for i, (gene, isoforms) in enumerate(many_to_one.items()):
    if i >= 5:  # 只显示前5个
        break
    print(f"{list(isoforms)} -> {gene}")

print(f"\nSummary: {len(one_to_many)} one-to-many, {len(many_to_one)} many-to-one")
# Out:
# One-to-many relationships:
# PB.10048 -> ['DDX23_RND1', 'RND1', 'DDX23']
# PB.10051 -> ['ENSG00000272822', 'ARF3', 'FKBP11', 'ARF3_RPL32P27']
# PB.10071 -> ['TUBA1A', 'TUBA1A_TUBA1B', 'TUBA1B']
# PB.10073 -> ['SPATS2', 'KCNH3']
# PB.10095 -> ['COX14', 'GPD1']
#
# Many-to-one relationships:
# ['PB.19112', 'PB.19114'] -> ABCA5
# ['PB.30464', 'PB.30457'] -> ABI3BP
# ['PB.17765', 'PB.17766'] -> ACSF3
# ['PB.29897', 'PB.29884'] -> ADAMTS9
# ['PB.15982', 'PB.15972'] -> ADAMTSL3
#
# Summary: 1839 one-to-many, 296 many-to-one

# %%
df['isoform_base'].nunique()
df['isoform'].nunique()
# Out:
# 290741
